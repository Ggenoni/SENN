# %% [markdown]
# # Evaluating Explainable AI <br> A Comparative Study of SENN, IG, and LIME
# by Alessandra Gandini and Gaudenzia Genoni
# Machine Learning for NLP II, Professor Stefano
# University of Trento, 2024/2025
# ***
# ### Notebook 1 - Mnist

# %% [markdown]
# Explain the project..........

# %% [markdown]
# ## 0. Preliminary set up and installatios

# %%
# !pip install matplotlib==3.5
# !pip install captum
# !pip install lime
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: matplotlib==3.5 in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (1.4.8)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.5) (1.17.0)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# Collecting captum
#   Using cached captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.11/dist-packages (from captum) (2.5.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.6->captum)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (10.3.5.147)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.6->captum)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.6->captum)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6->captum) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6->captum) (3.0.2)
# Using cached captum-0.7.0-py3-none-any.whl (1.3 MB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, captum
#   Attempting uninstall: nvidia-cudnn-cu12
#     WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# Successfully installed captum-0.7.0 nvidia-cudnn-cu12-9.1.0.70 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: lime in /usr/local/lib/python3.11/dist-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.1.10)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# WARNING: Ignoring invalid distribution ~vidia-cusparse-cu12 (/usr/local/lib/python3.11/dist-packages)

# %%
# Clone the repository
# !git clone https://github.com/Ggenoni/SENN.git
# Out:
# Cloning into 'SENN'...
# remote: Enumerating objects: 2801, done.
# remote: Counting objects: 100% (580/580), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 2801 (delta 450), reused 373 (delta 373), pack-reused 2221 (from 3)
# Receiving objects: 100% (2801/2801), 122.56 MiB | 12.09 MiB/s, done.
# Resolving deltas: 100% (1380/1380), done.

# %%
# Change directory
# %cd SENN
# Out:
# /content/SENN

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"PyTorch Version: {torch.__version__}")
# Out:
# CUDA Available: True
# CUDA Version: 12.1
# PyTorch Version: 2.5.1+cu121

# %%
! pwd
# Out:
# /content/SENN

# %%
# Connect to GitHub
# !git config --global user.email "gaudenzia.genoni@gmail.com"
# !git config --global user.name "Ggenoni"

# %% [markdown]
# ## 1. Training the SNEE model

# %%
! pwd
# Out:
# /content/SENN

# %%
# Train the model with our config file

# !python main.py --config configs/config.json
# Out:
# 2025-01-29 16:25:15.938873: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-29 16:25:15.959050: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-29 16:25:15.965020: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-29 16:25:15.982101: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-29 16:25:17.176704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ==================================================
#  EXPERIMENT: OUR_MODEL
# ==================================================
# {'aggregator': 'SumAggregator',
#  'batch_size': 200,
#  'cl_sizes': [1, 10, 20],
#  'concept_dim': 1,
#  'concept_reg': 1,
#  'conceptizer': 'ConvConceptizer',
#  'data_path': 'datasets/data/mnist_data',
#  'dataloader': 'mnist',
#  'device': 'cuda:0',
#  'dropout': 0.5,
#  'epochs': 40,
#  'eval_freq': 270,
#  'exp_name': 'OUR_MODEL',
#  'hidden_sizes': [320, 50],
#  'image_size': 28,
#  'lr': 0.0002,
#  'manual_seed': 29,
#  'num_classes': 10,
#  'num_concepts': 5,
#  'parameterizer': 'ConvParameterizer',
#  'print_freq': 100,
#  'robust_reg': 0.0001,
#  'robustness_loss': 'mnist_robustness_loss',
#  'sparsity_reg': 2e-05,
#  'train': True}
# Using device cuda:0
# Loading data ...
# SENN(
#   (conceptizer): ConvConceptizer(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(10, 5, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (2): ScalarMapping(
#         (layers): ModuleList(
#           (0-4): 5 x Linear(in_features=16, out_features=1, bias=True)
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(5, 16, kernel_size=(5, 5), stride=(2, 2))
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): ConvTranspose2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): ConvTranspose2d(8, 1, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#       )
#       (5): Tanh()
#     )
#     (unlinear): Linear(in_features=1, out_features=16, bias=True)
#   )
#   (parameterizer): ConvParameterizer(
#     (cl_layers): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ReLU()
#       (3): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#       (4): Dropout2d(p=0.5, inplace=False)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): ReLU()
#     )
#     (fc_layers): Sequential(
#       (0): Linear(in_features=320, out_features=50, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): Tanh()
#     )
#   )
#   (aggregator): SumAggregator()
# )
# Trainable Parameters: 28219
#
# Training begins...
# EPOCH:0 STEP:0
# Total Loss:3.421 	Classification Loss:2.297 	Robustness Loss:6.837 	Concept Loss:1.123 	Accuracy:0.145
# EPOCH:0 STEP:100
# Total Loss:1.906 	Classification Loss:1.075 	Robustness Loss:52.987 	Concept Loss:0.826 	Accuracy:0.680
# EPOCH:0 STEP:200
# Total Loss:1.417 	Classification Loss:0.617 	Robustness Loss:70.163 	Concept Loss:0.793 	Accuracy:0.825
#
# -------- Validation --------
# Total Loss:0.972 	Classification Loss:0.219 	Robustness Loss:0.000 	Concept Loss:0.752 	Accuracy:0.937
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[0]-Step[270].pt
#
# EPOCH:1 STEP:0
# Total Loss:1.300 	Classification Loss:0.541 	Robustness Loss:70.132 	Concept Loss:0.751 	Accuracy:0.840
# EPOCH:1 STEP:100
# Total Loss:1.147 	Classification Loss:0.421 	Robustness Loss:79.277 	Concept Loss:0.718 	Accuracy:0.855
# EPOCH:1 STEP:200
# Total Loss:1.086 	Classification Loss:0.372 	Robustness Loss:81.246 	Concept Loss:0.706 	Accuracy:0.895
#
# -------- Validation --------
# Total Loss:0.858 	Classification Loss:0.149 	Robustness Loss:0.000 	Concept Loss:0.709 	Accuracy:0.958
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[1]-Step[540].pt
#
# EPOCH:2 STEP:0
# Total Loss:1.072 	Classification Loss:0.349 	Robustness Loss:81.572 	Concept Loss:0.715 	Accuracy:0.905
# EPOCH:2 STEP:100
# Total Loss:1.013 	Classification Loss:0.336 	Robustness Loss:88.645 	Concept Loss:0.668 	Accuracy:0.910
# EPOCH:2 STEP:200
# Total Loss:0.953 	Classification Loss:0.269 	Robustness Loss:81.674 	Concept Loss:0.675 	Accuracy:0.930
#
# -------- Validation --------
# Total Loss:0.806 	Classification Loss:0.121 	Robustness Loss:0.000 	Concept Loss:0.685 	Accuracy:0.965
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[2]-Step[810].pt
#
# EPOCH:3 STEP:0
# Total Loss:0.827 	Classification Loss:0.175 	Robustness Loss:83.772 	Concept Loss:0.644 	Accuracy:0.960
# EPOCH:3 STEP:100
# Total Loss:1.006 	Classification Loss:0.309 	Robustness Loss:83.738 	Concept Loss:0.688 	Accuracy:0.885
# EPOCH:3 STEP:200
# Total Loss:0.926 	Classification Loss:0.255 	Robustness Loss:89.042 	Concept Loss:0.662 	Accuracy:0.920
#
# -------- Validation --------
# Total Loss:0.769 	Classification Loss:0.104 	Robustness Loss:0.000 	Concept Loss:0.665 	Accuracy:0.971
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[3]-Step[1080].pt
#
# EPOCH:4 STEP:0
# Total Loss:0.860 	Classification Loss:0.195 	Robustness Loss:88.210 	Concept Loss:0.655 	Accuracy:0.945
# EPOCH:4 STEP:100
# Total Loss:0.996 	Classification Loss:0.348 	Robustness Loss:85.515 	Concept Loss:0.640 	Accuracy:0.920
# EPOCH:4 STEP:200
# Total Loss:0.877 	Classification Loss:0.197 	Robustness Loss:76.787 	Concept Loss:0.673 	Accuracy:0.940
#
# -------- Validation --------
# Total Loss:0.746 	Classification Loss:0.096 	Robustness Loss:0.000 	Concept Loss:0.651 	Accuracy:0.975
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[4]-Step[1350].pt
#
# EPOCH:5 STEP:0
# Total Loss:0.905 	Classification Loss:0.224 	Robustness Loss:82.109 	Concept Loss:0.673 	Accuracy:0.935
# EPOCH:5 STEP:100
# Total Loss:0.901 	Classification Loss:0.261 	Robustness Loss:85.598 	Concept Loss:0.632 	Accuracy:0.935
# EPOCH:5 STEP:200
# Total Loss:0.982 	Classification Loss:0.308 	Robustness Loss:86.104 	Concept Loss:0.665 	Accuracy:0.890
#
# -------- Validation --------
# Total Loss:0.731 	Classification Loss:0.091 	Robustness Loss:0.000 	Concept Loss:0.641 	Accuracy:0.976
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[5]-Step[1620].pt
#
# EPOCH:6 STEP:0
# Total Loss:0.847 	Classification Loss:0.172 	Robustness Loss:78.071 	Concept Loss:0.668 	Accuracy:0.965
# EPOCH:6 STEP:100
# Total Loss:0.831 	Classification Loss:0.172 	Robustness Loss:78.653 	Concept Loss:0.651 	Accuracy:0.950
# EPOCH:6 STEP:200
# Total Loss:0.853 	Classification Loss:0.216 	Robustness Loss:86.420 	Concept Loss:0.629 	Accuracy:0.935
#
# -------- Validation --------
# Total Loss:0.724 	Classification Loss:0.090 	Robustness Loss:0.000 	Concept Loss:0.634 	Accuracy:0.977
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[6]-Step[1890].pt
#
# EPOCH:7 STEP:0
# Total Loss:0.815 	Classification Loss:0.162 	Robustness Loss:87.821 	Concept Loss:0.645 	Accuracy:0.940
# EPOCH:7 STEP:100
# Total Loss:0.880 	Classification Loss:0.240 	Robustness Loss:88.510 	Concept Loss:0.632 	Accuracy:0.935
# EPOCH:7 STEP:200
# Total Loss:0.878 	Classification Loss:0.250 	Robustness Loss:77.050 	Concept Loss:0.620 	Accuracy:0.915
#
# -------- Validation --------
# Total Loss:0.710 	Classification Loss:0.085 	Robustness Loss:0.000 	Concept Loss:0.625 	Accuracy:0.978
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[7]-Step[2160].pt
#
# EPOCH:8 STEP:0
# Total Loss:0.739 	Classification Loss:0.114 	Robustness Loss:82.124 	Concept Loss:0.617 	Accuracy:0.980
# EPOCH:8 STEP:100
# Total Loss:0.856 	Classification Loss:0.211 	Robustness Loss:78.972 	Concept Loss:0.637 	Accuracy:0.965
# EPOCH:8 STEP:200
# Total Loss:0.745 	Classification Loss:0.126 	Robustness Loss:82.267 	Concept Loss:0.610 	Accuracy:0.965
#
# -------- Validation --------
# Total Loss:0.699 	Classification Loss:0.081 	Robustness Loss:0.000 	Concept Loss:0.619 	Accuracy:0.979
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[8]-Step[2430].pt
#
# EPOCH:9 STEP:0
# Total Loss:0.847 	Classification Loss:0.226 	Robustness Loss:90.632 	Concept Loss:0.613 	Accuracy:0.940
# EPOCH:9 STEP:100
# Total Loss:0.826 	Classification Loss:0.192 	Robustness Loss:82.306 	Concept Loss:0.626 	Accuracy:0.960
# EPOCH:9 STEP:200
# Total Loss:0.781 	Classification Loss:0.160 	Robustness Loss:83.732 	Concept Loss:0.612 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.689 	Classification Loss:0.076 	Robustness Loss:0.000 	Concept Loss:0.613 	Accuracy:0.980
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[9]-Step[2700].pt
#
# EPOCH:10 STEP:0
# Total Loss:0.762 	Classification Loss:0.149 	Robustness Loss:83.728 	Concept Loss:0.604 	Accuracy:0.950
# EPOCH:10 STEP:100
# Total Loss:0.845 	Classification Loss:0.219 	Robustness Loss:77.726 	Concept Loss:0.618 	Accuracy:0.930
# EPOCH:10 STEP:200
# Total Loss:0.788 	Classification Loss:0.160 	Robustness Loss:81.558 	Concept Loss:0.621 	Accuracy:0.940
#
# -------- Validation --------
# Total Loss:0.682 	Classification Loss:0.073 	Robustness Loss:0.000 	Concept Loss:0.608 	Accuracy:0.982
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[10]-Step[2970].pt
#
# EPOCH:11 STEP:0
# Total Loss:0.811 	Classification Loss:0.208 	Robustness Loss:83.292 	Concept Loss:0.594 	Accuracy:0.945
# EPOCH:11 STEP:100
# Total Loss:0.682 	Classification Loss:0.081 	Robustness Loss:86.460 	Concept Loss:0.592 	Accuracy:0.975
# EPOCH:11 STEP:200
# Total Loss:0.808 	Classification Loss:0.186 	Robustness Loss:75.379 	Concept Loss:0.614 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.674 	Classification Loss:0.070 	Robustness Loss:0.000 	Concept Loss:0.604 	Accuracy:0.982
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[11]-Step[3240].pt
#
# EPOCH:12 STEP:0
# Total Loss:0.758 	Classification Loss:0.147 	Robustness Loss:80.953 	Concept Loss:0.603 	Accuracy:0.965
# EPOCH:12 STEP:100
# Total Loss:0.768 	Classification Loss:0.164 	Robustness Loss:80.845 	Concept Loss:0.595 	Accuracy:0.960
# EPOCH:12 STEP:200
# Total Loss:0.672 	Classification Loss:0.078 	Robustness Loss:78.461 	Concept Loss:0.586 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.669 	Classification Loss:0.068 	Robustness Loss:0.000 	Concept Loss:0.600 	Accuracy:0.981
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[12]-Step[3510].pt
#
# EPOCH:13 STEP:0
# Total Loss:0.879 	Classification Loss:0.241 	Robustness Loss:81.634 	Concept Loss:0.630 	Accuracy:0.935
# EPOCH:13 STEP:100
# Total Loss:0.695 	Classification Loss:0.092 	Robustness Loss:79.799 	Concept Loss:0.595 	Accuracy:0.975
# EPOCH:13 STEP:200
# Total Loss:0.727 	Classification Loss:0.125 	Robustness Loss:80.281 	Concept Loss:0.594 	Accuracy:0.955
#
# -------- Validation --------
# Total Loss:0.668 	Classification Loss:0.068 	Robustness Loss:0.000 	Concept Loss:0.599 	Accuracy:0.982
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[13]-Step[3780].pt
#
# EPOCH:14 STEP:0
# Total Loss:0.757 	Classification Loss:0.139 	Robustness Loss:86.983 	Concept Loss:0.609 	Accuracy:0.970
# EPOCH:14 STEP:100
# Total Loss:0.880 	Classification Loss:0.270 	Robustness Loss:84.840 	Concept Loss:0.602 	Accuracy:0.940
# EPOCH:14 STEP:200
# Total Loss:0.743 	Classification Loss:0.140 	Robustness Loss:78.704 	Concept Loss:0.595 	Accuracy:0.945
#
# -------- Validation --------
# Total Loss:0.661 	Classification Loss:0.065 	Robustness Loss:0.000 	Concept Loss:0.596 	Accuracy:0.982
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[14]-Step[4050].pt
#
# EPOCH:15 STEP:0
# Total Loss:0.714 	Classification Loss:0.112 	Robustness Loss:77.661 	Concept Loss:0.595 	Accuracy:0.960
# EPOCH:15 STEP:100
# Total Loss:0.752 	Classification Loss:0.123 	Robustness Loss:78.778 	Concept Loss:0.621 	Accuracy:0.965
# EPOCH:15 STEP:200
# Total Loss:0.737 	Classification Loss:0.125 	Robustness Loss:78.340 	Concept Loss:0.604 	Accuracy:0.960
#
# -------- Validation --------
# Total Loss:0.656 	Classification Loss:0.062 	Robustness Loss:0.000 	Concept Loss:0.594 	Accuracy:0.983
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[15]-Step[4320].pt
#
# EPOCH:16 STEP:0
# Total Loss:0.730 	Classification Loss:0.147 	Robustness Loss:85.336 	Concept Loss:0.575 	Accuracy:0.965
# EPOCH:16 STEP:100
# Total Loss:0.692 	Classification Loss:0.107 	Robustness Loss:80.121 	Concept Loss:0.577 	Accuracy:0.970
# EPOCH:16 STEP:200
# Total Loss:0.902 	Classification Loss:0.292 	Robustness Loss:80.653 	Concept Loss:0.602 	Accuracy:0.925
#
# -------- Validation --------
# Total Loss:0.653 	Classification Loss:0.062 	Robustness Loss:0.000 	Concept Loss:0.592 	Accuracy:0.983
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[16]-Step[4590].pt
#
# EPOCH:17 STEP:0
# Total Loss:0.730 	Classification Loss:0.135 	Robustness Loss:75.286 	Concept Loss:0.587 	Accuracy:0.960
# EPOCH:17 STEP:100
# Total Loss:0.731 	Classification Loss:0.150 	Robustness Loss:73.806 	Concept Loss:0.574 	Accuracy:0.960
# EPOCH:17 STEP:200
# Total Loss:0.723 	Classification Loss:0.124 	Robustness Loss:81.950 	Concept Loss:0.591 	Accuracy:0.970
#
# -------- Validation --------
# Total Loss:0.654 	Classification Loss:0.062 	Robustness Loss:0.000 	Concept Loss:0.591 	Accuracy:0.983
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[17]-Step[4860].pt
#
# EPOCH:18 STEP:0
# Total Loss:0.735 	Classification Loss:0.138 	Robustness Loss:77.365 	Concept Loss:0.589 	Accuracy:0.955
# EPOCH:18 STEP:100
# Total Loss:0.674 	Classification Loss:0.072 	Robustness Loss:81.237 	Concept Loss:0.593 	Accuracy:0.980
# EPOCH:18 STEP:200
# Total Loss:0.692 	Classification Loss:0.080 	Robustness Loss:76.978 	Concept Loss:0.604 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.654 	Classification Loss:0.064 	Robustness Loss:0.000 	Concept Loss:0.590 	Accuracy:0.983
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[18]-Step[5130].pt
#
# EPOCH:19 STEP:0
# Total Loss:0.785 	Classification Loss:0.197 	Robustness Loss:87.085 	Concept Loss:0.579 	Accuracy:0.940
# EPOCH:19 STEP:100
# Total Loss:0.853 	Classification Loss:0.249 	Robustness Loss:79.279 	Concept Loss:0.596 	Accuracy:0.940
# EPOCH:19 STEP:200
# Total Loss:0.798 	Classification Loss:0.188 	Robustness Loss:86.643 	Concept Loss:0.602 	Accuracy:0.955
#
# -------- Validation --------
# Total Loss:0.648 	Classification Loss:0.061 	Robustness Loss:0.000 	Concept Loss:0.588 	Accuracy:0.983
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[19]-Step[5400].pt
#
# EPOCH:20 STEP:0
# Total Loss:0.692 	Classification Loss:0.106 	Robustness Loss:72.177 	Concept Loss:0.579 	Accuracy:0.965
# EPOCH:20 STEP:100
# Total Loss:0.769 	Classification Loss:0.184 	Robustness Loss:83.586 	Concept Loss:0.577 	Accuracy:0.945
# EPOCH:20 STEP:200
# Total Loss:0.736 	Classification Loss:0.141 	Robustness Loss:79.667 	Concept Loss:0.587 	Accuracy:0.955
#
# -------- Validation --------
# Total Loss:0.648 	Classification Loss:0.061 	Robustness Loss:0.000 	Concept Loss:0.587 	Accuracy:0.984
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[20]-Step[5670].pt
#
# EPOCH:21 STEP:0
# Total Loss:0.757 	Classification Loss:0.166 	Robustness Loss:82.302 	Concept Loss:0.583 	Accuracy:0.955
# EPOCH:21 STEP:100
# Total Loss:0.665 	Classification Loss:0.071 	Robustness Loss:75.284 	Concept Loss:0.586 	Accuracy:0.990
# EPOCH:21 STEP:200
# Total Loss:0.700 	Classification Loss:0.122 	Robustness Loss:73.333 	Concept Loss:0.570 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.645 	Classification Loss:0.059 	Robustness Loss:0.000 	Concept Loss:0.586 	Accuracy:0.984
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[21]-Step[5940].pt
#
# EPOCH:22 STEP:0
# Total Loss:0.784 	Classification Loss:0.180 	Robustness Loss:76.835 	Concept Loss:0.596 	Accuracy:0.935
# EPOCH:22 STEP:100
# Total Loss:0.774 	Classification Loss:0.186 	Robustness Loss:79.300 	Concept Loss:0.580 	Accuracy:0.955
# EPOCH:22 STEP:200
# Total Loss:0.772 	Classification Loss:0.167 	Robustness Loss:77.021 	Concept Loss:0.597 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.642 	Classification Loss:0.058 	Robustness Loss:0.000 	Concept Loss:0.584 	Accuracy:0.984
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[22]-Step[6210].pt
#
# EPOCH:23 STEP:0
# Total Loss:0.787 	Classification Loss:0.176 	Robustness Loss:80.393 	Concept Loss:0.603 	Accuracy:0.965
# EPOCH:23 STEP:100
# Total Loss:0.740 	Classification Loss:0.138 	Robustness Loss:82.655 	Concept Loss:0.593 	Accuracy:0.975
# EPOCH:23 STEP:200
# Total Loss:0.747 	Classification Loss:0.168 	Robustness Loss:77.863 	Concept Loss:0.572 	Accuracy:0.965
#
# -------- Validation --------
# Total Loss:0.641 	Classification Loss:0.057 	Robustness Loss:0.000 	Concept Loss:0.584 	Accuracy:0.985
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[23]-Step[6480].pt
#
# EPOCH:24 STEP:0
# Total Loss:0.668 	Classification Loss:0.067 	Robustness Loss:78.597 	Concept Loss:0.593 	Accuracy:0.980
# EPOCH:24 STEP:100
# Total Loss:0.826 	Classification Loss:0.218 	Robustness Loss:86.808 	Concept Loss:0.599 	Accuracy:0.940
# EPOCH:24 STEP:200
# Total Loss:0.708 	Classification Loss:0.112 	Robustness Loss:77.871 	Concept Loss:0.588 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.640 	Classification Loss:0.058 	Robustness Loss:0.000 	Concept Loss:0.582 	Accuracy:0.985
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[24]-Step[6750].pt
#
# EPOCH:25 STEP:0
# Total Loss:0.702 	Classification Loss:0.110 	Robustness Loss:80.102 	Concept Loss:0.584 	Accuracy:0.960
# EPOCH:25 STEP:100
# Total Loss:0.709 	Classification Loss:0.128 	Robustness Loss:82.454 	Concept Loss:0.573 	Accuracy:0.970
# EPOCH:25 STEP:200
# Total Loss:0.729 	Classification Loss:0.132 	Robustness Loss:72.925 	Concept Loss:0.590 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.638 	Classification Loss:0.057 	Robustness Loss:0.000 	Concept Loss:0.581 	Accuracy:0.986
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[25]-Step[7020].pt
#
# EPOCH:26 STEP:0
# Total Loss:0.705 	Classification Loss:0.105 	Robustness Loss:81.736 	Concept Loss:0.592 	Accuracy:0.980
# EPOCH:26 STEP:100
# Total Loss:0.693 	Classification Loss:0.100 	Robustness Loss:80.886 	Concept Loss:0.585 	Accuracy:0.970
# EPOCH:26 STEP:200
# Total Loss:0.688 	Classification Loss:0.099 	Robustness Loss:71.944 	Concept Loss:0.582 	Accuracy:0.980
#
# -------- Validation --------
# Total Loss:0.636 	Classification Loss:0.056 	Robustness Loss:0.000 	Concept Loss:0.580 	Accuracy:0.985
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[26]-Step[7290].pt
#
# EPOCH:27 STEP:0
# Total Loss:0.784 	Classification Loss:0.199 	Robustness Loss:74.407 	Concept Loss:0.578 	Accuracy:0.935
# EPOCH:27 STEP:100
# Total Loss:0.662 	Classification Loss:0.089 	Robustness Loss:76.187 	Concept Loss:0.565 	Accuracy:0.975
# EPOCH:27 STEP:200
# Total Loss:0.716 	Classification Loss:0.132 	Robustness Loss:73.435 	Concept Loss:0.577 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.636 	Classification Loss:0.057 	Robustness Loss:0.000 	Concept Loss:0.579 	Accuracy:0.985
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[27]-Step[7560].pt
#
# EPOCH:28 STEP:0
# Total Loss:0.658 	Classification Loss:0.095 	Robustness Loss:80.896 	Concept Loss:0.554 	Accuracy:0.970
# EPOCH:28 STEP:100
# Total Loss:0.714 	Classification Loss:0.130 	Robustness Loss:78.666 	Concept Loss:0.576 	Accuracy:0.970
# EPOCH:28 STEP:200
# Total Loss:0.695 	Classification Loss:0.126 	Robustness Loss:79.867 	Concept Loss:0.562 	Accuracy:0.955
#
# -------- Validation --------
# Total Loss:0.633 	Classification Loss:0.055 	Robustness Loss:0.000 	Concept Loss:0.578 	Accuracy:0.986
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[28]-Step[7830].pt
#
# EPOCH:29 STEP:0
# Total Loss:0.643 	Classification Loss:0.076 	Robustness Loss:78.048 	Concept Loss:0.559 	Accuracy:0.970
# EPOCH:29 STEP:100
# Total Loss:0.664 	Classification Loss:0.086 	Robustness Loss:87.048 	Concept Loss:0.569 	Accuracy:0.980
# EPOCH:29 STEP:200
# Total Loss:0.742 	Classification Loss:0.141 	Robustness Loss:73.378 	Concept Loss:0.593 	Accuracy:0.940
#
# -------- Validation --------
# Total Loss:0.634 	Classification Loss:0.056 	Robustness Loss:0.000 	Concept Loss:0.578 	Accuracy:0.985
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[29]-Step[8100].pt
#
# EPOCH:30 STEP:0
# Total Loss:0.747 	Classification Loss:0.164 	Robustness Loss:82.087 	Concept Loss:0.574 	Accuracy:0.975
# EPOCH:30 STEP:100
# Total Loss:0.693 	Classification Loss:0.111 	Robustness Loss:74.068 	Concept Loss:0.574 	Accuracy:0.975
# EPOCH:30 STEP:200
# Total Loss:0.695 	Classification Loss:0.116 	Robustness Loss:78.643 	Concept Loss:0.572 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.630 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.576 	Accuracy:0.985
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[30]-Step[8370].pt
#
# EPOCH:31 STEP:0
# Total Loss:0.732 	Classification Loss:0.154 	Robustness Loss:82.263 	Concept Loss:0.570 	Accuracy:0.960
# EPOCH:31 STEP:100
# Total Loss:0.751 	Classification Loss:0.171 	Robustness Loss:88.304 	Concept Loss:0.571 	Accuracy:0.955
# EPOCH:31 STEP:200
# Total Loss:0.658 	Classification Loss:0.087 	Robustness Loss:74.958 	Concept Loss:0.564 	Accuracy:0.980
#
# -------- Validation --------
# Total Loss:0.627 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.575 	Accuracy:0.986
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[31]-Step[8640].pt
#
# EPOCH:32 STEP:0
# Total Loss:0.703 	Classification Loss:0.130 	Robustness Loss:76.637 	Concept Loss:0.565 	Accuracy:0.960
# EPOCH:32 STEP:100
# Total Loss:0.675 	Classification Loss:0.100 	Robustness Loss:83.806 	Concept Loss:0.567 	Accuracy:0.960
# EPOCH:32 STEP:200
# Total Loss:0.679 	Classification Loss:0.079 	Robustness Loss:79.120 	Concept Loss:0.592 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.629 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.575 	Accuracy:0.987
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[32]-Step[8910].pt
#
# EPOCH:33 STEP:0
# Total Loss:0.687 	Classification Loss:0.093 	Robustness Loss:81.919 	Concept Loss:0.586 	Accuracy:0.970
# EPOCH:33 STEP:100
# Total Loss:0.765 	Classification Loss:0.171 	Robustness Loss:80.172 	Concept Loss:0.586 	Accuracy:0.945
# EPOCH:33 STEP:200
# Total Loss:0.742 	Classification Loss:0.142 	Robustness Loss:81.036 	Concept Loss:0.593 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.628 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.574 	Accuracy:0.987
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[33]-Step[9180].pt
#
# EPOCH:34 STEP:0
# Total Loss:0.706 	Classification Loss:0.122 	Robustness Loss:81.623 	Concept Loss:0.575 	Accuracy:0.960
# EPOCH:34 STEP:100
# Total Loss:0.662 	Classification Loss:0.096 	Robustness Loss:86.576 	Concept Loss:0.557 	Accuracy:0.980
# EPOCH:34 STEP:200
# Total Loss:0.737 	Classification Loss:0.163 	Robustness Loss:80.096 	Concept Loss:0.566 	Accuracy:0.955
#
# -------- Validation --------
# Total Loss:0.626 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.573 	Accuracy:0.987
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[34]-Step[9450].pt
#
# EPOCH:35 STEP:0
# Total Loss:0.730 	Classification Loss:0.141 	Robustness Loss:79.077 	Concept Loss:0.581 	Accuracy:0.970
# EPOCH:35 STEP:100
# Total Loss:0.683 	Classification Loss:0.091 	Robustness Loss:76.039 	Concept Loss:0.584 	Accuracy:0.970
# EPOCH:35 STEP:200
# Total Loss:0.706 	Classification Loss:0.137 	Robustness Loss:85.970 	Concept Loss:0.561 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.623 	Classification Loss:0.051 	Robustness Loss:0.000 	Concept Loss:0.572 	Accuracy:0.987
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/best_model.pt
#
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[35]-Step[9720].pt
#
# EPOCH:36 STEP:0
# Total Loss:0.704 	Classification Loss:0.131 	Robustness Loss:80.298 	Concept Loss:0.564 	Accuracy:0.970
# EPOCH:36 STEP:100
# Total Loss:0.661 	Classification Loss:0.075 	Robustness Loss:77.516 	Concept Loss:0.579 	Accuracy:0.985
# EPOCH:36 STEP:200
# Total Loss:0.682 	Classification Loss:0.078 	Robustness Loss:78.603 	Concept Loss:0.596 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.625 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.572 	Accuracy:0.987
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[36]-Step[9990].pt
#
# EPOCH:37 STEP:0
# Total Loss:0.625 	Classification Loss:0.070 	Robustness Loss:78.515 	Concept Loss:0.548 	Accuracy:0.980
# EPOCH:37 STEP:100
# Total Loss:0.668 	Classification Loss:0.089 	Robustness Loss:73.937 	Concept Loss:0.571 	Accuracy:0.980
# EPOCH:37 STEP:200
# Total Loss:0.636 	Classification Loss:0.080 	Robustness Loss:78.104 	Concept Loss:0.549 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.625 	Classification Loss:0.054 	Robustness Loss:0.000 	Concept Loss:0.571 	Accuracy:0.986
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[37]-Step[10260].pt
#
# EPOCH:38 STEP:0
# Total Loss:0.715 	Classification Loss:0.131 	Robustness Loss:82.846 	Concept Loss:0.575 	Accuracy:0.980
# EPOCH:38 STEP:100
# Total Loss:0.696 	Classification Loss:0.130 	Robustness Loss:75.463 	Concept Loss:0.559 	Accuracy:0.960
# EPOCH:38 STEP:200
# Total Loss:0.673 	Classification Loss:0.108 	Robustness Loss:71.350 	Concept Loss:0.558 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.621 	Classification Loss:0.053 	Robustness Loss:0.000 	Concept Loss:0.569 	Accuracy:0.987
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[38]-Step[10530].pt
#
# EPOCH:39 STEP:0
# Total Loss:0.743 	Classification Loss:0.168 	Robustness Loss:77.579 	Concept Loss:0.567 	Accuracy:0.950
# EPOCH:39 STEP:100
# Total Loss:0.765 	Classification Loss:0.189 	Robustness Loss:73.913 	Concept Loss:0.569 	Accuracy:0.945
# EPOCH:39 STEP:200
# Total Loss:0.735 	Classification Loss:0.173 	Robustness Loss:83.892 	Concept Loss:0.553 	Accuracy:0.960
#
# -------- Validation --------
# Total Loss:0.621 	Classification Loss:0.052 	Robustness Loss:0.000 	Concept Loss:0.570 	Accuracy:0.987
# ----------------------------
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[39]-Step[10800].pt
#
# Please wait while we finalize...
# Checkpoint saved @ results/OUR_MODEL/checkpoints/Epoch[39]-Step[10800].pt

# %%
# !git add -f results/
# Out:
# git: 'add.' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add

# %%
# !git commit -m "Force add results folder"
# !git remote set-url origin https://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@github.com/Ggenoni/SENN.git
# !git push --force origin master
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 90, done.
# Counting objects: 100% (90/90), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (64/64), done.
# Writing objects: 100% (64/64), 13.73 MiB | 5.91 MiB/s, done.
# Total 64 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Ggenoni/SENN.git
#    39de561..4bd6ad5  master -> master

# %% [markdown]
# ### 2. SENN learned concepts

# %% [markdown]
# ##### 2.1 Imports and set up

# %%
import json
import torch
import random
import numpy as np
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from pathlib import Path
from types import SimpleNamespace
from importlib import import_module

# %%
! pwd
# Out:
# /content/SENN

# %%
from senn.models.losses import *
from senn.models.parameterizers import *
from senn.models.conceptizers import *
from senn.models.aggregators import *
from senn.models.senn import SENN, DiSENN

# %%
from senn.datasets.dataloaders import get_dataloader
from senn.utils.plot_utils import show_explanations, show_prototypes, plot_lambda_accuracy, get_comparison_plot

# %%
def load_checkpoint(config):
    model_file = Path('results') / config.exp_name / "checkpoints" / "best_model.pt"
    return torch.load(model_file, config.device)

# %%
def get_config(filename):
    config_path = Path('configs')
    config_file = config_path / filename
    with open(config_file, 'r') as f:
        config = json.load(f)

    return SimpleNamespace(**config)

# %%
def accuracy(model, dataloader, config):
    accuracies = []
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Auto-detect device

    model.to(device)  # Ensure model is on correct device
    with torch.no_grad():
        for i, (x, labels) in enumerate(dataloader):
            x = x.float().to(device)  # Move input tensors to device
            labels = labels.long().to(device)  # Move labels to device
            y_pred, (concepts, relevances), _ = model(x)
            accuracies.append((y_pred.argmax(axis=1) == labels).float().mean().item())

    accuracy = np.array(accuracies).mean()
    print(f"Test Mean Accuracy: {accuracy * 100:.3f} %")

# %%
mnist_config = get_config("config.json")

# %% [markdown]
# ##### 2.2 Getting the dataset

# %%
_, _, mnist_test_dl = get_dataloader(mnist_config)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [Errno 111] Connection refused>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to datasets/data/mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 43.0MB/s]
# Extracting datasets/data/mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to datasets/data/mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [Errno 111] Connection refused>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to datasets/data/mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.26MB/s]
# Extracting datasets/data/mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to datasets/data/mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [Errno 111] Connection refused>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to datasets/data/mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 10.6MB/s]
# Extracting datasets/data/mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to datasets/data/mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [Errno 111] Connection refused>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to datasets/data/mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.86MB/s]
# Extracting datasets/data/mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to datasets/data/mnist_data/MNIST/raw

# %% [markdown]
# ##### 2.3 Getting the model and loading the trained parameters

# %%
conceptizer = ConvConceptizer(**mnist_config.__dict__)
parameterizer = ConvParameterizer(**mnist_config.__dict__)
aggregator = SumAggregator(**mnist_config.__dict__)

mnist_SENN = SENN(conceptizer, parameterizer, aggregator)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Construct checkpoint path properly
checkpoint_path = Path("results") / mnist_config.exp_name / "checkpoints" / "best_model.pt"

# Load the checkpoint
mnist_checkpoint = torch.load(checkpoint_path, map_location=device)
mnist_SENN.load_state_dict(mnist_checkpoint['model_state'])
mnist_SENN.to(device)  # Move model to the appropriate device
# Out:
# <ipython-input-14-5281cb37beaf>:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mnist_checkpoint = torch.load(checkpoint_path, map_location=device)
# SENN(
#   (conceptizer): ConvConceptizer(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(10, 5, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (2): ScalarMapping(
#         (layers): ModuleList(
#           (0-4): 5 x Linear(in_features=16, out_features=1, bias=True)
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(5, 16, kernel_size=(5, 5), stride=(2, 2))
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): ConvTranspose2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): ConvTranspose2d(8, 1, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#       )
#       (5): Tanh()
#     )
#     (unlinear): Linear(in_features=1, out_features=16, bias=True)
#   )
#   (parameterizer): ConvParameterizer(
#     (cl_layers): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ReLU()
#       (3): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#       (4): Dropout2d(p=0.5, inplace=False)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): ReLU()
#     )
#     (fc_layers): Sequential(
#       (0): Linear(in_features=320, out_features=50, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): Tanh()
#     )
#   )
#   (aggregator): SumAggregator()
# )

# %% [markdown]
# ##### 2.4 Evaluating accuracy on the test sets

# %%
accuracy(mnist_SENN, mnist_test_dl, mnist_config)
# Out:
# Test Mean Accuracy: 98.900 %

# %% [markdown]
# ##### 2.5 Concept prototypes

# %%
show_prototypes(mnist_SENN, mnist_test_dl, 'activation')

# %% [markdown]
# ##### 2.6 Getting sample indeces
# 1 randomly chosen sample for each class (10 in total).
# Setting seeds allows reproducibility of the experiment.

# %%
import torch
import random
import numpy as np

# Ensure reproducibility
torch.manual_seed(10)
np.random.seed(10)
random.seed(10)

# Get the dataset
dataset = mnist_test_dl.dataset
total_samples = len(dataset)

# Initialize a dictionary to store one sample per class
class_indices = {i: None for i in range(10)}  # Classes are 0-9
random_indices = []

# Shuffle the dataset indices to ensure randomness
shuffled_indices = torch.randperm(total_samples).tolist()

# Iterate through the shuffled indices
for idx in shuffled_indices:
    img, label = dataset[idx]
    if class_indices[label] is None:
        class_indices[label] = idx
        random_indices.append((idx, label))  # Append both index and label
    # Break the loop once we have one sample per class
    if len(random_indices) == 10:
        break

# Sort the indices by label
random_indices_sorted = sorted(random_indices, key=lambda x: x[1])

# Extract only the indices in the correct order
random_indices = [idx for idx, _ in random_indices_sorted]

print("Ordered random indices, one per class:", random_indices)
# Out:
# Ordered random indices, one per class: [6937, 7468, 837, 3531, 5561, 8415, 5034, 6762, 7735, 3992]

# %% [markdown]
# ##### 2.7 SENN explanations

# %%
# Rememer to save the images!!!!

show_explanations(mnist_SENN, mnist_test_dl, 'mnist', selected_indices=random_indices)

# %% [markdown]
# ##### 2.8 Ablation study and statistics on relevance scores

# %%
from senn.utils.custom_functions import evaluate_concept_ablation,analyze_relevance_scores_by_predicted_class, analyze_class_specific_relevance

# %%
# Ablation study

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
mnist_SENN.to(device)

concepts = [0, 1, 2, 3, 4]

for i in range(len(concepts)):

    ablated_concepts= concepts[:i]+concepts[i+1:]

    # Evaluate concept ablation
    original_preds, ablated_preds, impact = evaluate_concept_ablation(
        mnist_SENN, mnist_test_dl, ablated_concepts, device=device
    )

    # Calculate the percentage of predictions affected by ablation
    percentage_changed = 100 * sum(impact) / len(impact)
    print(f"Percentage of Predictions Changed by Ablating Concepts {ablated_concepts}: {percentage_changed:.2f}%")
    # Analyze results
    print(f"Original Predictions: {original_preds[:10]}")
    print(f"Ablated Predictions: {ablated_preds[:10]}")
    print(f"Impact on Predictions: {impact[:10]} (True = Changed, False = Unchanged)")
    print("\n\n")
# Out:
# Percentage of Predictions Changed by Ablating Concepts [1, 2, 3, 4]: 0.60%
# Original Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Ablated Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)
#
#
#
# Percentage of Predictions Changed by Ablating Concepts [0, 2, 3, 4]: 0.76%
# Original Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Ablated Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)
#
#
#
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 3, 4]: 0.67%
# Original Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Ablated Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)
#
#
#
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 2, 4]: 0.55%
# Original Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Ablated Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)
#
#
#
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 2, 3]: 0.60%
# Original Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Ablated Predictions: [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of concepts
num_concepts = 5

# Analyze relevance scores
relevance_stats = analyze_relevance_scores_by_predicted_class(
    mnist_SENN, mnist_test_dl, num_concepts=num_concepts, device=device
)

# Extract data
concepts = [f"Concept {int(concept) + 1}" for concept in relevance_stats.keys()]
means = [stats["mean"] for stats in relevance_stats.values()]
std_devs = [stats["std"] for stats in relevance_stats.values()]

# Create a bar chart with error bars
plt.figure(figsize=(8, 5))
plt.bar(concepts, means, yerr=std_devs, capsize=5, color='royalblue', alpha=0.75)

# Formatting
plt.xlabel("Concepts")
plt.ylabel("Relevance Score")
plt.title("Relevance Scores by Concept")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()


# Display statistics
print("Relevance Score Statistics:")
for concept, stats in relevance_stats.items():
    print(f"Concept {int(concept)+1}: Mean = {stats['mean']:.4f}, Std = {stats['std']:.4f}")
# Out:
# Relevance Score Statistics:
# Concept 1: Mean = -0.6667, Std = 0.1979
# Concept 2: Mean = 0.6741, Std = 0.1974
# Concept 3: Mean = -0.6482, Std = 0.2107
# Concept 4: Mean = 0.6609, Std = 0.2086
# Concept 5: Mean = -0.6713, Std = 0.2037

# %%
# Number of classes in MNIST
num_classes = 10

# Number of concepts
num_concepts = 5

# Analyze class-specific relevance
class_relevance_stats = analyze_class_specific_relevance(
    mnist_SENN, mnist_test_dl, num_classes=num_classes, num_concepts=num_concepts, device=device
)

import matplotlib.pyplot as plt
import numpy as np

# Define color palette for better distinction
colors = ['royalblue', 'darkorange', 'forestgreen', 'crimson', 'purple', 'deepskyblue']

# Visualize relevance scores by class
for cls, stats in class_relevance_stats.items():
    concept_means = [stat["mean"] for stat in stats.values()]
    concept_stds = [stat["std"] for stat in stats.values()]

    plt.figure(figsize=(9, 5))
    x = np.arange(num_concepts)

    # Use different colors for classes
    color = colors[cls % len(colors)]

    # Plot bar chart with error bars
    plt.bar(x, concept_means, yerr=concept_stds, capsize=6, alpha=0.8, color=color, label=f"Class {cls}")

    # Formatting
    plt.xticks(x, [f"Concept {i+1}" for i in range(num_concepts)], fontsize=11)
    plt.xlabel("Concepts", fontsize=12)
    plt.ylabel("Relevance Score", fontsize=12)
    plt.title(f"Relevance Scores (Theta) for Class {cls}", fontsize=14, fontweight="bold")
    plt.grid(axis="y", linestyle="--", alpha=0.7)

    # Adjust y-axis dynamically to accommodate negative values
    y_min = min(concept_means) - max(concept_stds) - 0.05
    y_max = max(concept_means) + max(concept_stds) + 0.05
    plt.ylim(y_min, y_max)

    # Add horizontal line at y=0 for reference
    plt.axhline(y=0, color="black", linewidth=1.2, linestyle="--", alpha=0.7)

    # Add data labels (adjusting position for negative values)
    for i, v in enumerate(concept_means):
        offset = 0.02 if v >= 0 else -0.05  # Adjust text placement
        plt.text(i, v + offset, f"{v:.2f}", ha='center', fontsize=10, fontweight='bold', color="black")

    plt.legend()
    plt.show()


# Display the statistics
for cls, stats in class_relevance_stats.items():
    print(f"Class {cls} Relevance Scores:")
    for concept, values in stats.items():
        print(f"  {concept}: Mean = {values['mean']:.4f}, Std = {values['std']:.4f}")
# Out:
# Class 0 Relevance Scores:
#   Concept 1: Mean = -0.7095, Std = 0.1473
#   Concept 2: Mean = 0.7132, Std = 0.1939
#   Concept 3: Mean = -0.7137, Std = 0.1631
#   Concept 4: Mean = 0.6820, Std = 0.1542
#   Concept 5: Mean = -0.7093, Std = 0.1503
# Class 1 Relevance Scores:
#   Concept 1: Mean = -0.6682, Std = 0.1486
#   Concept 2: Mean = 0.6656, Std = 0.1414
#   Concept 3: Mean = -0.6480, Std = 0.1400
#   Concept 4: Mean = 0.6638, Std = 0.1629
#   Concept 5: Mean = -0.7574, Std = 0.1244
# Class 2 Relevance Scores:
#   Concept 1: Mean = -0.6807, Std = 0.1991
#   Concept 2: Mean = 0.6834, Std = 0.2046
#   Concept 3: Mean = -0.6494, Std = 0.2310
#   Concept 4: Mean = 0.6987, Std = 0.2152
#   Concept 5: Mean = -0.6946, Std = 0.1952
# Class 3 Relevance Scores:
#   Concept 1: Mean = -0.6677, Std = 0.1757
#   Concept 2: Mean = 0.6902, Std = 0.1802
#   Concept 3: Mean = -0.6389, Std = 0.1935
#   Concept 4: Mean = 0.6693, Std = 0.1919
#   Concept 5: Mean = -0.6978, Std = 0.1760
# Class 4 Relevance Scores:
#   Concept 1: Mean = -0.7028, Std = 0.1868
#   Concept 2: Mean = 0.7086, Std = 0.1869
#   Concept 3: Mean = -0.7411, Std = 0.1735
#   Concept 4: Mean = 0.7769, Std = 0.1722
#   Concept 5: Mean = -0.7663, Std = 0.1739
# Class 5 Relevance Scores:
#   Concept 1: Mean = -0.6922, Std = 0.1796
#   Concept 2: Mean = 0.6426, Std = 0.1944
#   Concept 3: Mean = -0.6736, Std = 0.2023
#   Concept 4: Mean = 0.5812, Std = 0.1982
#   Concept 5: Mean = -0.6301, Std = 0.1972
# Class 6 Relevance Scores:
#   Concept 1: Mean = -0.7344, Std = 0.1887
#   Concept 2: Mean = 0.7531, Std = 0.1841
#   Concept 3: Mean = -0.7466, Std = 0.2111
#   Concept 4: Mean = 0.7789, Std = 0.1859
#   Concept 5: Mean = -0.7884, Std = 0.1811
# Class 7 Relevance Scores:
#   Concept 1: Mean = -0.7458, Std = 0.2038
#   Concept 2: Mean = 0.7381, Std = 0.1802
#   Concept 3: Mean = -0.6697, Std = 0.2086
#   Concept 4: Mean = 0.6858, Std = 0.2098
#   Concept 5: Mean = -0.6250, Std = 0.2080
# Class 8 Relevance Scores:
#   Concept 1: Mean = -0.4811, Std = 0.2020
#   Concept 2: Mean = 0.6260, Std = 0.1987
#   Concept 3: Mean = -0.4934, Std = 0.2182
#   Concept 4: Mean = 0.5031, Std = 0.2010
#   Concept 5: Mean = -0.5417, Std = 0.2071
# Class 9 Relevance Scores:
#   Concept 1: Mean = -0.5849, Std = 0.1960
#   Concept 2: Mean = 0.5206, Std = 0.2025
#   Concept 3: Mean = -0.5136, Std = 0.1941
#   Concept 4: Mean = 0.5627, Std = 0.2132
#   Concept 5: Mean = -0.4927, Std = 0.1923

# %% [markdown]
# ### 3. Integrated Gradients

# %% [markdown]
# ##### 3.1 Imports and set up

# %%
from captum.attr import IntegratedGradients
from skimage.metrics import structural_similarity as ssim
from torchvision.transforms import functional as TF
import random

# %%
from senn.models.senn import SENNWrapper

# %%
from senn.utils.custom_functions import compute_completeness_gap, sensitivity_analysis, apply_challenging_transformations, predict_on_masked_pixels

# %%
# Use our SENN wrapper to make the model compatible with Integrated Gradients implemented in the captum library
wrapped_model = SENNWrapper(mnist_SENN)
ig = IntegratedGradients(wrapped_model)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
wrapped_model = wrapped_model.to(device)

# %% [markdown]
# ##### 3.2 Getting the data samples

# %%
## Uncomment the code below to run the analysis on other test samples

# Ensure reproducibility
"""torch.manual_seed(110)
np.random.seed(110)
random.seed(100)"""

# Number of random samples to analyze
"""num_samples = 5"""

# Get the dataset
"""dataset = mnist_test_dl.dataset
total_samples = len(dataset)"""

# Randomly pick indices for the samples
"""random_indices = torch.randint(0, total_samples, (num_samples,)).tolist()"""

# %% [markdown]
# ##### 3.3 Attribution maps and completeness gap

# %%
# Get the device of the model
device = next(wrapped_model.parameters()).device

for i, random_index in enumerate(random_indices):
    # Retrieve the sample and label
    sample_input, sample_label = dataset[random_index]

    # Add batch dimension and move to the model's device
    sample_input = sample_input.unsqueeze(0).to(device)

    # Define the baseline (e.g., a black image) and move it to the same device
    baseline = torch.zeros_like(sample_input).to(device)

    # Get the predicted label
    with torch.no_grad():
        predictions = wrapped_model(sample_input)
        predicted_label = torch.argmax(predictions, dim=1).item()

    # Compute completeness gap and attributions
    completeness_gap, attributions = compute_completeness_gap(
        wrapped_model, sample_input, baseline, predicted_label
    )

    print(f"Sample {i + 1}: Completeness Gap = {completeness_gap:.4f}")

    # Prepare data for visualization
    attributions = attributions.squeeze().detach().to(device).numpy()
    attributions = attributions / np.max(np.abs(attributions))  # Normalize
    original_image = sample_input.squeeze().to(device).numpy()

    # Determine bounds for the colormap
    cmap_bound = np.abs(attributions).max()

    # Create a 1-row, 2-column plot
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    # Original image
    ax[0].imshow(original_image, cmap="gray")
    ax[0].set_title(f"Original Image\nLabel: {sample_label}")
    ax[0].axis("off")

    # Attributions (Raw)
    im = ax[1].imshow(attributions, vmin=-cmap_bound, vmax=cmap_bound, cmap="PiYG")
    ax[1].set_title(f"Attributions\nPredicted: {predicted_label}")
    ax[1].axis("off")

    # Add a colorbar to the attributions plot
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust colorbar position
    cbar = fig.colorbar(im, cax=cbar_ax)
    cbar.set_label("Attribution Value", rotation=270, labelpad=15)

    # Manually adjust spacing between plots
    fig.subplots_adjust(wspace=0.3, hspace=0.3)

    # Display the plot
    plt.show()

    print("\n\n")
# Out:
# Sample 1: Completeness Gap = 0.0031
# Sample 2: Completeness Gap = 0.0034
# Sample 3: Completeness Gap = 0.0012
# Sample 4: Completeness Gap = 0.0090
# Sample 5: Completeness Gap = 0.0066
# Sample 6: Completeness Gap = 0.0021
# Sample 7: Completeness Gap = 0.0026
# Sample 8: Completeness Gap = 0.0002
# Sample 9: Completeness Gap = 0.0066
# Sample 10: Completeness Gap = 0.0085

# %% [markdown]
# ##### 3.4 Evaluating stabilty on IG

# %% [markdown]
# ##### 3.4.1 Attribution maps for slightly perturbed inputs

# %%
# Compute sensitivity scores and visualize attributions for each random sample
for i, random_index in enumerate(random_indices):
    # Retrieve the sample and label
    sample_input, sample_label = dataset[random_index]

    # Add batch dimension and move input to CPU
    sample_input = sample_input.unsqueeze(0).to(device)

    # Define the baseline (e.g., a black image) and move it to CPU
    baseline = torch.zeros_like(sample_input).to(device)

    # Get the predicted label
    with torch.no_grad():
        predictions = wrapped_model(sample_input)
        predicted_label = torch.argmax(predictions, dim=1).item()

    # Perform sensitivity analysis with high noise level
    sensitivity_scores, original_attributions, all_attributions, perturbed_predictions = sensitivity_analysis(
        wrapped_model, sample_input, baseline, predicted_label, noise_std=0.5, num_perturbations=5
    )

    print(f"Sample {i + 1}: True Label = {sample_label}, Original Prediction = {predicted_label}")
    print(f"Sensitivity Scores = {sensitivity_scores}")
    print(f"Average Similarity: {np.mean(sensitivity_scores):.4f}")
    print(f"Perturbed Predictions: {perturbed_predictions}")

    # Prepare data for visualization
    original_attributions = original_attributions.squeeze()
    cmap_bound = max(np.abs(original_attributions.max()), np.abs(original_attributions.min()))

    # Create figure for attributions
    fig, axes = plt.subplots(1, len(all_attributions) + 1, figsize=(15, 5))

    # Plot original attributions
    axes[0].imshow(original_attributions, cmap="PiYG", vmin=-cmap_bound, vmax=cmap_bound)
    axes[0].set_title("Original Attribution")
    axes[0].axis("off")

    # Plot perturbed attributions
    for j, perturbed_attribution in enumerate(all_attributions):
        perturbed_attribution = perturbed_attribution.squeeze()
        axes[j + 1].imshow(perturbed_attribution, cmap="PiYG", vmin=-cmap_bound, vmax=cmap_bound)
        axes[j + 1].set_title(f"Perturbed {j + 1}")
        axes[j + 1].axis("off")

    # Adjust layout for the plot
    plt.tight_layout()
    plt.show()

    # Visualize original and perturbed inputs
    fig, axes = plt.subplots(1, len(all_attributions) + 1, figsize=(15, 5))
    axes[0].imshow(sample_input.squeeze().numpy(), cmap="gray")
    axes[0].set_title(f"Original Input\nTrue: {sample_label}, Pred: {predicted_label}")
    axes[0].axis("off")

    for j, _ in enumerate(all_attributions):
        noise = torch.randn_like(sample_input) * 0.5  # High noise level
        perturbed_input = (sample_input + noise).squeeze().numpy()
        axes[j + 1].imshow(perturbed_input, cmap="gray")
        axes[j + 1].set_title(f"Perturbed {j + 1}\nPred: {perturbed_predictions[j]}")
        axes[j + 1].axis("off")

    # Adjust layout for inputs
    plt.tight_layout()
    plt.show()

    print("\n\n")
# Out:
# Sample 1: True Label = 0, Original Prediction = 0
# Sensitivity Scores = [0.5160486601486521, 0.5850396298301797, 0.5780129316108996, 0.5750241109795657, 0.6106934117289093]
# Average Similarity: 0.5730
# Perturbed Predictions: [0, 0, 0, 0, 0]
# Sample 2: True Label = 1, Original Prediction = 1
# Sensitivity Scores = [0.5340729194386239, 0.38284396733208353, 0.42236135120541723, 0.4429642513734752, 0.4711039373293766]
# Average Similarity: 0.4507
# Perturbed Predictions: [1, 1, 1, 1, 1]
# Sample 3: True Label = 2, Original Prediction = 2
# Sensitivity Scores = [0.4355700425779841, 0.3382294551103232, 0.49789001836789326, 0.4776855749306798, 0.5958163432680977]
# Average Similarity: 0.4690
# Perturbed Predictions: [2, 2, 2, 2, 2]
# Sample 4: True Label = 3, Original Prediction = 3
# Sensitivity Scores = [0.519725871067289, 0.6419126248718605, 0.5342444478748879, 0.6436468293845318, 0.551428387485765]
# Average Similarity: 0.5782
# Perturbed Predictions: [3, 3, 3, 3, 3]
# Sample 5: True Label = 4, Original Prediction = 4
# Sensitivity Scores = [0.681065251772339, 0.6166508415461327, 0.6519551861157183, 0.6810702250530455, 0.71532811675365]
# Average Similarity: 0.6692
# Perturbed Predictions: [4, 4, 4, 4, 4]
# Sample 6: True Label = 5, Original Prediction = 5
# Sensitivity Scores = [0.6614678636287854, 0.6025215068762885, 0.7147085304762733, 0.6997999545886799, 0.6839456008304631]
# Average Similarity: 0.6725
# Perturbed Predictions: [5, 5, 5, 5, 5]
# Sample 7: True Label = 6, Original Prediction = 6
# Sensitivity Scores = [0.6744307980588762, 0.5384689637987938, 0.6426029403081404, 0.5850574455440813, 0.6046114759437147]
# Average Similarity: 0.6090
# Perturbed Predictions: [6, 6, 6, 6, 6]
# Sample 8: True Label = 7, Original Prediction = 7
# Sensitivity Scores = [0.5492193768662132, 0.5764826942790975, 0.5560219443190944, 0.5458348759411267, 0.4354564424103893]
# Average Similarity: 0.5326
# Perturbed Predictions: [7, 7, 7, 7, 7]
# Sample 9: True Label = 8, Original Prediction = 8
# Sensitivity Scores = [0.6182348491199192, 0.5190186828887524, 0.5162528133794867, 0.4927082307907678, 0.5163700514711835]
# Average Similarity: 0.5325
# Perturbed Predictions: [8, 8, 8, 8, 8]
# Sample 10: True Label = 9, Original Prediction = 9
# Sensitivity Scores = [0.5905644331266827, 0.6183723449783596, 0.545173387068131, 0.6380808254167347, 0.6554551265627261]
# Average Similarity: 0.6095
# Perturbed Predictions: [9, 9, 9, 9, 9]

# %% [markdown]
# ##### 3.4.2 Attribution maps for heavily perturbed inputs

# %%
# Compute sensitivity scores and visualize attributions for each random sample
for i, random_index in enumerate(random_indices):
    # Retrieve the sample and label
    sample_input, sample_label = dataset[random_index]

    # Add batch dimension
    sample_input = sample_input.unsqueeze(0)

    # Define the baseline (e.g., a black image)
    baseline = torch.zeros_like(sample_input)

    # Get the predicted label
    predictions = wrapped_model(sample_input)
    predicted_label = torch.argmax(predictions, dim=1).item()

    # Perform sensitivity analysis with challenging transformations
    sensitivity_scores, original_attributions, all_attributions, perturbed_predictions = sensitivity_analysis(
        wrapped_model, sample_input, baseline, predicted_label, challenging_transformations=True, num_perturbations=5
    )

    print(f"Sample {i + 1}: True Label = {sample_label}, Original Prediction = {predicted_label}")
    print(f"Sensitivity Scores = {sensitivity_scores}")
    print(f"Average Similarity: {np.mean(sensitivity_scores):.4f}")
    print(f"Perturbed Predictions: {perturbed_predictions}")

    # Prepare data for visualization
    original_attributions = original_attributions.squeeze()
    cmap_bound = max(np.abs(original_attributions.max()), np.abs(original_attributions.min()))

    # Create figure for attributions
    fig, axes = plt.subplots(1, len(all_attributions) + 1, figsize=(15, 5))

    # Plot original attributions
    axes[0].imshow(original_attributions, cmap="PiYG", vmin=-cmap_bound, vmax=cmap_bound)
    axes[0].set_title("Original Attribution")
    axes[0].axis("off")

    # Plot perturbed attributions
    for j, perturbed_attribution in enumerate(all_attributions):
        perturbed_attribution = perturbed_attribution.squeeze()
        axes[j + 1].imshow(perturbed_attribution, cmap="PiYG", vmin=-cmap_bound, vmax=cmap_bound)
        axes[j + 1].set_title(f"Perturbed {j + 1}")
        axes[j + 1].axis("off")

    # Adjust layout for attributions
    plt.tight_layout()
    plt.show()

    # Visualize perturbed inputs
    fig, axes = plt.subplots(1, len(all_attributions) + 1, figsize=(15, 5))
    axes[0].imshow(sample_input.squeeze().numpy(), cmap="gray")
    axes[0].set_title(f"Original Input\nTrue: {sample_label}, Pred: {predicted_label}")
    axes[0].axis("off")

    for j in range(len(all_attributions)):
        perturbed_input = apply_challenging_transformations(sample_input)
        axes[j + 1].imshow(perturbed_input.squeeze().numpy(), cmap="gray")
        axes[j + 1].set_title(f"Perturbed Input {j + 1}\nPred: {perturbed_predictions[j]}")
        axes[j + 1].axis("off")

    # Adjust layout for inputs
    plt.tight_layout()
    plt.show()

    print("\n\n")
# Out:
# Sample 1: True Label = 0, Original Prediction = 0
# Sensitivity Scores = [0.3732900960971478, 0.327278916947564, 0.1271671267297198, 0.1029262379322362, 0.058668241786144236]
# Average Similarity: 0.1979
# Perturbed Predictions: [0, 0, 0, 9, 7]
# Sample 2: True Label = 1, Original Prediction = 1
# Sensitivity Scores = [0.02946393130468572, 0.07597490397669304, 0.1269720719960816, 0.09368947485854226, 0.03913841458970748]
# Average Similarity: 0.0730
# Perturbed Predictions: [4, 4, 5, 5, 7]
# Sample 3: True Label = 2, Original Prediction = 2
# Sensitivity Scores = [0.061776891415669576, 0.045633549877121954, 0.3821242122971456, 0.19734543023801862, 0.10796145550268413]
# Average Similarity: 0.1590
# Perturbed Predictions: [2, 7, 2, 2, 2]
# Sample 4: True Label = 3, Original Prediction = 3
# Sensitivity Scores = [0.11952158676623427, 0.1608776767612285, 0.013279023813926445, 0.06004899299941442, 0.28756845731910236]
# Average Similarity: 0.1283
# Perturbed Predictions: [3, 3, 5, 5, 3]
# Sample 5: True Label = 4, Original Prediction = 4
# Sensitivity Scores = [0.18028537261210933, 0.025562686074892104, 0.0562260716043009, 0.3052647350207868, 0.03894650949610956]
# Average Similarity: 0.1213
# Perturbed Predictions: [4, 8, 8, 4, 7]
# Sample 6: True Label = 5, Original Prediction = 5
# Sensitivity Scores = [0.2955014448304896, 0.28787483648729817, 0.050452419762161894, 0.04982715863054031, 0.02006816720969482]
# Average Similarity: 0.1407
# Perturbed Predictions: [5, 5, 5, 0, 8]
# Sample 7: True Label = 6, Original Prediction = 6
# Sensitivity Scores = [0.16914739568776938, 0.17162157428154914, 0.009847545508843031, 0.056236840868438165, 0.00739975897597366]
# Average Similarity: 0.0829
# Perturbed Predictions: [9, 6, 4, 4, 8]
# Sample 8: True Label = 7, Original Prediction = 7
# Sensitivity Scores = [0.006156662203775677, 0.03440601990773438, 0.0480446623080261, 0.09773481268171415, 0.20391233999669447]
# Average Similarity: 0.0781
# Perturbed Predictions: [2, 2, 7, 5, 7]
# Sample 9: True Label = 8, Original Prediction = 8
# Sensitivity Scores = [0.01762906633277299, 0.0649543059197397, 0.06172955709168733, 0.0007896218341270101, 0.07053179210092521]
# Average Similarity: 0.0431
# Perturbed Predictions: [7, 9, 8, 0, 8]
# Sample 10: True Label = 9, Original Prediction = 9
# Sensitivity Scores = [0.19818465290859097, 0.16276438020090864, 0.12456399787989433, 0.04278860879543063, 0.08658782456924456]
# Average Similarity: 0.1230
# Perturbed Predictions: [9, 9, 2, 9, 9]

# %% [markdown]
# ##### 3.5 Evaluating faithfulness on IG by masking most relevant pixels

# %%
for idx, random_index in enumerate(random_indices):
    sample_image, sample_label = dataset[random_index]
    sample_input = sample_image.unsqueeze(0).to(device)  # Convert to tensor & move to GPU

    print(f"Sample {idx + 1} - True Label: {sample_label}")

    # Compute IG explanations before calling predict_on_masked_pixels
    baseline = torch.zeros_like(sample_input).to(device)  # Use black image as baseline
    with torch.no_grad():
        predictions, _, _ = mnist_SENN(sample_input)  # Fix: Extract only predictions
        predicted_label = torch.argmax(predictions, dim=1).item()

    # Compute IG attributions
    _, ig_attributions = compute_completeness_gap(wrapped_model, sample_input, baseline, predicted_label)

    # Convert attributions to numpy
    ig_attributions = ig_attributions.squeeze().cpu().numpy()

    # Now call the function with correctly computed IG
    predict_on_masked_pixels(sample_image.squeeze().numpy(), mnist_SENN, ig_attributions, predicted_label)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 1 - True Label: 0
# Original Confidence for Predicted Label 0: 1.00
#
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 0
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.99%
#     Predicted Label After Masking: 2
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 2 - True Label: 1
# Original Confidence for Predicted Label 1: 1.00
#
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 1
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.67
#     Confidence Drop: 32.67%
#     Predicted Label After Masking: 1
# Sample 3 - True Label: 2
# Original Confidence for Predicted Label 2: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 2
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 2
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.13%
#     Predicted Label After Masking: 2
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.94
#     Confidence Drop: 6.23%
#     Predicted Label After Masking: 2
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.02
#     Confidence Drop: 98.12%
#     Predicted Label After Masking: 1
# Sample 4 - True Label: 3
# Original Confidence for Predicted Label 3: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 3
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.99%
#     Predicted Label After Masking: 7
# Sample 5 - True Label: 4
# Original Confidence for Predicted Label 4: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 4
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 4
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 8
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.98%
#     Predicted Label After Masking: 7
# Sample 6 - True Label: 5
# Original Confidence for Predicted Label 5: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 5
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.96
#     Confidence Drop: 3.79%
#     Predicted Label After Masking: 5
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.12
#     Confidence Drop: 87.68%
#     Predicted Label After Masking: 3
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 6
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.19
#     Confidence Drop: 81.11%
#     Predicted Label After Masking: 2
# Sample 7 - True Label: 6
# Original Confidence for Predicted Label 6: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 6
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.99%
#     Predicted Label After Masking: 2
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 8
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
# Sample 8 - True Label: 7
# Original Confidence for Predicted Label 7: 1.00
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 7
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.98
#     Confidence Drop: 2.07%
#     Predicted Label After Masking: 7
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 3
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 3
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 3
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 9 - True Label: 8
# Original Confidence for Predicted Label 8: 1.00
#
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 8
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 8
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-100 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 8
#
# Top-200 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 8
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 6
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 10 - True Label: 9
# Original Confidence for Predicted Label 9: 1.00
#
# Top-10 Pixels Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 9
#
# Top-50 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-100 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.98%
#     Predicted Label After Masking: 4
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-200 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.99%
#     Predicted Label After Masking: 3
#
# Top-500 Pixels Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7

# %% [markdown]
# ##### 3.6 Pearson correlation

# %% [markdown]
# ### 4. LIME

# %% [markdown]
# ##### 4.1 Impotrs and set up

# %%
# Import needed libraries
from lime import lime_image
from skimage.segmentation import mark_boundaries, slic
from skimage.color import gray2rgb, rgb2gray, label2rgb
from lime.wrappers.scikit_image import SegmentationAlgorithm
from functools import partial

# %%
from senn.utils.custom_functions import predict_function, predict_on_masked_superpixels, segmenter

# %%
# Initialize the LIME Image Explainer
explainer = lime_image.LimeImageExplainer()

# %% [markdown]
# ##### 4.2 Getting the data samples

# %%
## Uncomment the code below to run the analysis on other test samples

# Ensure reproducibility
"""torch.manual_seed(110)
np.random.seed(110)
random.seed(100)"""

# Number of random samples to analyze
"""num_samples = 5"""

# Get the dataset
"""dataset = mnist_test_dl.dataset
total_samples = len(dataset)"""

# Randomly pick indices for the samples
"""random_indices = torch.randint(0, total_samples, (num_samples,)).tolist()"""

# %% [markdown]
# ##### 4.3 Superpixel segmentation and LIME explanations

# %%
# Bind the model to the prediction function
predict_with_model = partial(predict_function, model=mnist_SENN)

num_samples = 10

# Initialize the figure with 4 columns: Original, Superpixel Segmentation, Segmentation Map, and LIME Explanation
fig, axes = plt.subplots(num_samples, 4, figsize=(20, 5 * num_samples))

for i, random_index in enumerate(random_indices):
    # Select the image and label at the random index
    sample_image, sample_label = dataset[random_index]
    sample_image = sample_image.squeeze(0).numpy()  # Convert to 2D array

    # Convert grayscale image to RGB
    sample_image_rgb = gray2rgb(sample_image)  # Convert grayscale to RGB (HxWxC)

    # Generate LIME explanation
    explanation = explainer.explain_instance(
        image=sample_image_rgb,
        classifier_fn=predict_with_model,
        top_labels=1,
        hide_color=0,
        num_samples=1000,
        segmentation_fn=segmenter
    )

    # Get the explanation mask
    temp, mask = explanation.get_image_and_mask(
        label=explanation.top_labels[0],
        positive_only=True,  # Highlight only positive contributions
        num_features=10,
        hide_rest=False
    )

    # Extract explanation score (sum of positive contributions)
    explanation_score = sum(
        weight for feature, weight in explanation.local_exp[explanation.top_labels[0]]
        if weight > 0
    )

    # Clip the temp image to ensure valid intensity values
    temp = np.clip(temp, 0, 1)

    # Generate the LIME explanation overlay
    rgb_output = label2rgb(mask, temp, bg_label=0)

    # Clip the RGB output to valid range for floats ([0, 1])
    rgb_output = np.clip(rgb_output, 0, 1)

    # Extract segmentation mask from LIME explanation
    segments = explanation.segments  # Superpixel segment map

    # Visualize original image
    axes[i, 0].imshow(sample_image, cmap='gray')
    axes[i, 0].set_title(f"Original Image\nTrue Label: {sample_label}")
    axes[i, 0].axis('off')

    # Visualize superpixel segmentation boundaries
    axes[i, 1].imshow(mark_boundaries(sample_image_rgb, segments))
    axes[i, 1].set_title("Superpixel Segmentation")
    axes[i, 1].axis('off')

    # Visualize the segmentation map (each superpixel with a unique color)
    axes[i, 2].imshow(segments)  # Use a colormap that differentiates segments
    axes[i, 2].set_title("Superpixel Segmentation Map")
    axes[i, 2].axis('off')

    # Visualize LIME explanation with overlay
    axes[i, 3].imshow(rgb_output, interpolation='nearest')
    axes[i, 3].set_title(
        f"LIME Explanation\nPredicted Label: {explanation.top_labels[0]}\nScore: {explanation_score:.2f}"
    )
    axes[i, 3].axis('off')

# Adjust layout for better visualization
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##### 4.4 LIME explanations for forced missclassifications

# %%
# Get one data sample

data_iter = iter(mnist_test_dl)
images, labels = next(data_iter)
random_index = 118

# %%
# Initialize the figure for a 2x5 grid (10 classes in total)
fig, axes = plt.subplots(2, 5, figsize=(15, 6))


# Select the image and label at the random index
sample_image = images[random_index].squeeze(0).numpy()  # Convert to 2D array
sample_label = labels[random_index].item()  # Get label as integer

# Convert grayscale image to RGB
sample_image_rgb = gray2rgb(sample_image)  # Convert grayscale to RGB (HxWxC)

# Bind the model to the prediction function
predict_with_model = partial(predict_function, model=mnist_SENN)


# Generate LIME explanation for the fixed sample
explanation = explainer.explain_instance(
    image=sample_image_rgb,
    classifier_fn=predict_with_model,
    top_labels=10,  # Ensure LIME evaluates all classes (0-9)
    hide_color=0,
    num_samples=1000,
    segmentation_fn=segmenter
)

# Loop over all labels (0-9)
for label in range(10):
    # Get the explanation mask for the current label
    temp, mask = explanation.get_image_and_mask(
        label=label,  # Force LIME to generate explanation for the given label
        positive_only=True,  # Highlight only positive contributions
        num_features=10,
        hide_rest=False
    )

    # Ensure no negative intensities in `temp`
    temp = np.clip(temp, 0, 1)  # Clip to valid range [0, 1]

    # Extract explanation score for the current label
    explanation_score = sum(
        weight for feature, weight in explanation.local_exp[label]
        if weight > 0
    )

    # Generate the LIME explanation overlay
    rgb_output = label2rgb(mask, temp, bg_label=0)

    # Clip the RGB output to valid range for floats ([0, 1])
    rgb_output = np.clip(rgb_output, 0, 1)

    # Determine grid position
    row, col = divmod(label, 5)

    # Plot the LIME explanation in the grid
    axes[row, col].imshow(rgb_output, interpolation='nearest')
    axes[row, col].set_title(
        f"Positive for {label}\nScore: {explanation_score:.2f}", fontsize=10
    )
    axes[row, col].axis('off')

# Adjust layout for better visualization
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ##### 4.5 Evaluating faithfulness on LIME by masking most relevant superpixels

# %%
for idx, random_index in enumerate(random_indices):
    sample_image, sample_label = dataset[random_index]
    # Get the sample image and label
    sample_image = sample_image.squeeze(0).numpy()  # Convert to 2D array

    print(f"Sample {idx + 1} - True Label: {sample_label}")

    # Visualize the impact of masking superpixels
    predict_on_masked_superpixels(sample_image, mnist_SENN)
# Out:
# Sample 1 - True Label: 0
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Original Confidence for Predicted Label 0: 1.00
# Top Superpixel Importance Scores: [(33, 0.4940704239021126), (15, 0.2284124790084575), (22, 0.20748749783787412), (43, 0.20094588604584643), (49, 0.07924570393211906), (36, 0.07283983682609044), (38, 0.07075112207348484), (27, 0.0653893381400848), (19, 0.06061782452584554), (34, 0.058570365304330185)]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 0
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
# Sample 2 - True Label: 1
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Original Confidence for Predicted Label 1: 1.00
# Top Superpixel Importance Scores: [(32, 0.3818907455192327), (41, 0.34248484518374994), (31, 0.08923383958038843), (24, 0.0772701186182594), (37, 0.070401243603937), (14, 0.06582930930441623), (55, 0.054941089300052134), (57, 0.053276339452521734), (49, 0.049702532997323266), (45, 0.04894084004814378)]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 1
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
# Sample 3 - True Label: 2
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Original Confidence for Predicted Label 2: 1.00
# Top Superpixel Importance Scores: [(50, 0.3650083150400252), (47, 0.22106889765690832), (17, 0.10384188243124294), (29, 0.0931978027825258), (49, 0.08569641099249756), (12, 0.05622183667460085), (32, 0.043581907071184436), (24, 0.04327760636076437), (40, 0.03964621996509187), (43, 0.032430411801729314)]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 2
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
# Sample 4 - True Label: 3
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 3: 1.00
# Top Superpixel Importance Scores: [(16, 0.17101374715293055), (30, 0.15802144311715963), (23, 0.0898886019272582), (13, 0.07438612542480717), (50, 0.06994617051715045), (31, 0.0649633826205167), (38, 0.062366600680209085), (45, 0.05220970244872304), (46, 0.05139695655595288), (51, 0.045689807304874736)]
#
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 3
#
# Top-3 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.02%
#     Predicted Label After Masking: 3
#
# Top-5 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.49%
#     Predicted Label After Masking: 3
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 1
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 5 - True Label: 4
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 4: 1.00
# Top Superpixel Importance Scores: [(31, 0.5719152512161471), (34, 0.21094952115152496), (30, 0.13301103628633063), (35, 0.060673825502375864), (27, 0.05709991205799406), (46, 0.05423695200881274), (53, 0.050966883323353494), (22, 0.04911831619551477), (42, 0.04168150808923471), (47, 0.0354088927689682)]
#
# Top-1 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
# Sample 6 - True Label: 5
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 5: 1.00
# Top Superpixel Importance Scores: [(24, 0.21514681549910825), (47, 0.12096709745835196), (31, 0.1161866494238239), (16, 0.06591035563814178), (40, 0.057050650509984376), (41, 0.05346674056719392), (18, 0.04679838895737056), (36, 0.040923969389671404), (60, 0.033809846413071144), (29, 0.02974487743960702)]
#
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 5
#
# Top-3 Masked:
#     Perturbed Confidence: 0.05
#     Confidence Drop: 95.01%
#     Predicted Label After Masking: 6
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 6
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 6
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#     Predicted Label After Masking: 6
# Sample 7 - True Label: 6
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 6: 1.00
# Top Superpixel Importance Scores: [(37, 0.3495090980501175), (41, 0.28935128972711116), (50, 0.12845329197206853), (44, 0.10551005951065659), (29, 0.08325182834563968), (28, 0.07437048476318818), (15, 0.054102307002123394), (26, 0.048678134977371036), (42, 0.0481163193139813), (14, 0.03781818868623618)]
#
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 6
#
# Top-3 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 6
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 4
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 4
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 4
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Sample 8 - True Label: 7
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 7: 1.00
# Top Superpixel Importance Scores: [(22, 0.2859546018074752), (21, 0.2832457586520576), (25, 0.11400310571837582), (41, 0.10314621790073494), (49, 0.0829352107382301), (16, 0.07689895774088158), (30, 0.07512117117872481), (43, 0.07451650024416184), (40, 0.05565503296761791), (52, 0.04522018172942834)]
#
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 7
#
# Top-3 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 7
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.91%
#     Predicted Label After Masking: 3
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.99%
#     Predicted Label After Masking: 3
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 99.95%
#     Predicted Label After Masking: 1
# Sample 9 - True Label: 8
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original Confidence for Predicted Label 8: 1.00
# Top Superpixel Importance Scores: [(23, 0.36414025978082126), (33, 0.3018632883161143), (26, 0.22124018662338693), (36, 0.1953070178020523), (48, 0.08618665921396411), (42, 0.07818001292122286), (45, 0.07120620459037318), (27, 0.0701381719683266), (21, 0.06711092812837004), (34, 0.06312811580317547)]
#
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 8
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#     Predicted Label After Masking: 2
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 2
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 5
# Sample 10 - True Label: 9
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Original Confidence for Predicted Label 9: 1.00
# Top Superpixel Importance Scores: [(25, 0.5074537916041539), (37, 0.4345731854615317), (34, 0.3281742619656824), (24, 0.1979447589672503), (41, 0.0726050487586976), (12, 0.06841473212234231), (44, 0.059548517159657074), (21, 0.044125061901287996), (19, 0.039501635181097186), (11, 0.03809732323324556)]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Top-1 Masked:
#     Perturbed Confidence: 1.00
#     Confidence Drop: 0.00%
#     Predicted Label After Masking: 9
#
# Top-3 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-5 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-10 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
#
# Top-20 Masked:
#     Perturbed Confidence: 0.00
#     Confidence Drop: 100.00%
#     Predicted Label After Masking: 7
