# %% [markdown]
# # Evaluating Explainable AI: A Comparative Study of SENN, IG, and LIME
# by Alessandra Gandini and Gaudenzia Genoni
# Machine Learning for NLP II, Professor Stefano
# University of Trento, 2024/2025
# ***
# ### Notebook 2 - Confounded mnist

# %% [markdown]
# Explain the project....

# %% [markdown]
# ## 0. Preliminary set up and installatios

# %%
# !pip install matplotlib==3.5
# !pip install captum
# !pip install lime
# Out:
# Requirement already satisfied: matplotlib==3.5 in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (1.4.8)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.5) (1.17.0)
# Collecting captum
#   Using cached captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.11/dist-packages (from captum) (2.5.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.6->captum)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.6->captum)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.6->captum)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.6->captum)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.6->captum)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.6->captum)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.6->captum)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6->captum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6->captum) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6->captum) (3.0.2)
# Using cached captum-0.7.0-py3-none-any.whl (1.3 MB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, captum
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed captum-0.7.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting lime
#   Using cached lime-0.2.0.1.tar.gz (275 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.1.10)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=9d025627c967fe1808b2dbe540a26f54895bf75257ce6b1851f64934b8946665
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
# Clone the repository
# !git clone https://github.com/Ggenoni/SENN.git
# Out:
# Cloning into 'SENN'...
# remote: Enumerating objects: 2469, done.
# remote: Counting objects: 100% (462/462), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 2469 (delta 374), reused 421 (delta 365), pack-reused 2007 (from 1)
# Receiving objects: 100% (2469/2469), 115.14 MiB | 12.71 MiB/s, done.
# Resolving deltas: 100% (1281/1281), done.
# Updating files: 100% (305/305), done.

# %%
# Change directory
# %cd SENN
# Out:
# /content/SENN

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"PyTorch Version: {torch.__version__}")
# Out:
# CUDA Available: True
# CUDA Version: 12.4
# PyTorch Version: 2.5.1+cu124

# %%
! pwd
# Out:
# /content/SENN

# %%
# Connect to GitHub
# !git config --global user.email "gaudenzia.genoni@gmail.com"
# !git config --global user.name "Ggenoni"

# %% [markdown]
# ## 1. Training the SNEE model

# %%
! pwd
# Out:
# /content/SENN

# %%
# Train the model with our config file

# !python main.py --config configs/conf_mnist_config.json
# Out:
# 2025-01-30 11:46:11.572900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738237571.605875     974 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738237571.615898     974 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ==================================================
#  EXPERIMENT: CONF_FASHION_MNIST
# ==================================================
# {'aggregator': 'SumAggregator',
#  'batch_size': 200,
#  'cl_sizes': [1, 10, 20],
#  'concept_dim': 1,
#  'concept_reg': 1,
#  'conceptizer': 'ConvConceptizer',
#  'data_path': 'datasets/data/conf_mnist_data',
#  'dataloader': 'confounded-mnist',
#  'device': 'cuda:0',
#  'dropout': 0.5,
#  'epochs': 40,
#  'eval_freq': 270,
#  'exp_name': 'CONF_FASHION_MNIST',
#  'hidden_sizes': [320, 50],
#  'image_size': 28,
#  'lr': 0.0002,
#  'manual_seed': 29,
#  'num_classes': 10,
#  'num_concepts': 5,
#  'parameterizer': 'ConvParameterizer',
#  'print_freq': 100,
#  'robust_reg': 0.0001,
#  'robustness_loss': 'mnist_robustness_loss',
#  'sparsity_reg': 2e-05,
#  'train': True}
# Using device cuda:0
# Loading data ...
# SENN(
#   (conceptizer): ConvConceptizer(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(10, 5, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (2): ScalarMapping(
#         (layers): ModuleList(
#           (0-4): 5 x Linear(in_features=16, out_features=1, bias=True)
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(5, 16, kernel_size=(5, 5), stride=(2, 2))
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): ConvTranspose2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): ConvTranspose2d(8, 1, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#       )
#       (5): Tanh()
#     )
#     (unlinear): Linear(in_features=1, out_features=16, bias=True)
#   )
#   (parameterizer): ConvParameterizer(
#     (cl_layers): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ReLU()
#       (3): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#       (4): Dropout2d(p=0.5, inplace=False)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): ReLU()
#     )
#     (fc_layers): Sequential(
#       (0): Linear(in_features=320, out_features=50, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): Tanh()
#     )
#   )
#   (aggregator): SumAggregator()
# )
# Trainable Parameters: 28219
#
# Training begins...
# EPOCH:0 STEP:0
# Total Loss:2.829 	Classification Loss:2.314 	Robustness Loss:5.228 	Concept Loss:0.515 	Accuracy:0.095
# EPOCH:0 STEP:100
# Total Loss:1.541 	Classification Loss:1.072 	Robustness Loss:67.939 	Concept Loss:0.462 	Accuracy:0.655
# EPOCH:0 STEP:200
# Total Loss:0.993 	Classification Loss:0.558 	Robustness Loss:109.519 	Concept Loss:0.423 	Accuracy:0.830
#
# -------- Validation --------
# Total Loss:0.524 	Classification Loss:0.125 	Robustness Loss:0.000 	Concept Loss:0.399 	Accuracy:0.966
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[0]-Step[270].pt
#
# EPOCH:1 STEP:0
# Total Loss:0.854 	Classification Loss:0.443 	Robustness Loss:117.348 	Concept Loss:0.400 	Accuracy:0.855
# EPOCH:1 STEP:100
# Total Loss:0.760 	Classification Loss:0.359 	Robustness Loss:135.734 	Concept Loss:0.387 	Accuracy:0.900
# EPOCH:1 STEP:200
# Total Loss:0.630 	Classification Loss:0.228 	Robustness Loss:129.232 	Concept Loss:0.389 	Accuracy:0.935
#
# -------- Validation --------
# Total Loss:0.450 	Classification Loss:0.057 	Robustness Loss:0.000 	Concept Loss:0.393 	Accuracy:0.983
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[1]-Step[540].pt
#
# EPOCH:2 STEP:0
# Total Loss:0.630 	Classification Loss:0.226 	Robustness Loss:130.465 	Concept Loss:0.390 	Accuracy:0.940
# EPOCH:2 STEP:100
# Total Loss:0.610 	Classification Loss:0.222 	Robustness Loss:127.634 	Concept Loss:0.376 	Accuracy:0.920
# EPOCH:2 STEP:200
# Total Loss:0.518 	Classification Loss:0.123 	Robustness Loss:130.655 	Concept Loss:0.382 	Accuracy:0.950
#
# -------- Validation --------
# Total Loss:0.416 	Classification Loss:0.033 	Robustness Loss:0.000 	Concept Loss:0.383 	Accuracy:0.990
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[2]-Step[810].pt
#
# EPOCH:3 STEP:0
# Total Loss:0.479 	Classification Loss:0.099 	Robustness Loss:124.926 	Concept Loss:0.368 	Accuracy:0.980
# EPOCH:3 STEP:100
# Total Loss:0.556 	Classification Loss:0.160 	Robustness Loss:117.473 	Concept Loss:0.384 	Accuracy:0.965
# EPOCH:3 STEP:200
# Total Loss:0.510 	Classification Loss:0.125 	Robustness Loss:123.069 	Concept Loss:0.373 	Accuracy:0.970
#
# -------- Validation --------
# Total Loss:0.394 	Classification Loss:0.021 	Robustness Loss:0.000 	Concept Loss:0.372 	Accuracy:0.993
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[3]-Step[1080].pt
#
# EPOCH:4 STEP:0
# Total Loss:0.525 	Classification Loss:0.146 	Robustness Loss:117.993 	Concept Loss:0.367 	Accuracy:0.965
# EPOCH:4 STEP:100
# Total Loss:0.511 	Classification Loss:0.140 	Robustness Loss:112.823 	Concept Loss:0.360 	Accuracy:0.960
# EPOCH:4 STEP:200
# Total Loss:0.448 	Classification Loss:0.065 	Robustness Loss:108.152 	Concept Loss:0.371 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.376 	Classification Loss:0.015 	Robustness Loss:0.000 	Concept Loss:0.360 	Accuracy:0.995
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[4]-Step[1350].pt
#
# EPOCH:5 STEP:0
# Total Loss:0.457 	Classification Loss:0.076 	Robustness Loss:110.257 	Concept Loss:0.370 	Accuracy:0.970
# EPOCH:5 STEP:100
# Total Loss:0.494 	Classification Loss:0.133 	Robustness Loss:109.341 	Concept Loss:0.350 	Accuracy:0.965
# EPOCH:5 STEP:200
# Total Loss:0.485 	Classification Loss:0.114 	Robustness Loss:101.409 	Concept Loss:0.360 	Accuracy:0.965
#
# -------- Validation --------
# Total Loss:0.361 	Classification Loss:0.010 	Robustness Loss:0.000 	Concept Loss:0.350 	Accuracy:0.996
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[5]-Step[1620].pt
#
# EPOCH:6 STEP:0
# Total Loss:0.448 	Classification Loss:0.081 	Robustness Loss:96.018 	Concept Loss:0.358 	Accuracy:0.975
# EPOCH:6 STEP:100
# Total Loss:0.428 	Classification Loss:0.068 	Robustness Loss:96.671 	Concept Loss:0.351 	Accuracy:0.975
# EPOCH:6 STEP:200
# Total Loss:0.467 	Classification Loss:0.118 	Robustness Loss:92.178 	Concept Loss:0.340 	Accuracy:0.970
#
# -------- Validation --------
# Total Loss:0.349 	Classification Loss:0.008 	Robustness Loss:0.000 	Concept Loss:0.341 	Accuracy:0.997
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[6]-Step[1890].pt
#
# EPOCH:7 STEP:0
# Total Loss:0.421 	Classification Loss:0.064 	Robustness Loss:96.586 	Concept Loss:0.347 	Accuracy:0.985
# EPOCH:7 STEP:100
# Total Loss:0.430 	Classification Loss:0.083 	Robustness Loss:97.974 	Concept Loss:0.337 	Accuracy:0.975
# EPOCH:7 STEP:200
# Total Loss:0.392 	Classification Loss:0.056 	Robustness Loss:98.466 	Concept Loss:0.326 	Accuracy:0.980
#
# -------- Validation --------
# Total Loss:0.331 	Classification Loss:0.005 	Robustness Loss:0.000 	Concept Loss:0.325 	Accuracy:0.998
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[7]-Step[2160].pt
#
# EPOCH:8 STEP:0
# Total Loss:0.391 	Classification Loss:0.061 	Robustness Loss:81.507 	Concept Loss:0.322 	Accuracy:0.985
# EPOCH:8 STEP:100
# Total Loss:0.378 	Classification Loss:0.043 	Robustness Loss:86.105 	Concept Loss:0.327 	Accuracy:0.995
# EPOCH:8 STEP:200
# Total Loss:0.347 	Classification Loss:0.033 	Robustness Loss:86.812 	Concept Loss:0.305 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.310 	Classification Loss:0.003 	Robustness Loss:0.000 	Concept Loss:0.307 	Accuracy:0.998
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[8]-Step[2430].pt
#
# EPOCH:9 STEP:0
# Total Loss:0.364 	Classification Loss:0.048 	Robustness Loss:87.519 	Concept Loss:0.308 	Accuracy:0.990
# EPOCH:9 STEP:100
# Total Loss:0.403 	Classification Loss:0.087 	Robustness Loss:87.500 	Concept Loss:0.307 	Accuracy:0.985
# EPOCH:9 STEP:200
# Total Loss:0.364 	Classification Loss:0.061 	Robustness Loss:84.546 	Concept Loss:0.295 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.296 	Classification Loss:0.002 	Robustness Loss:0.000 	Concept Loss:0.294 	Accuracy:0.999
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[9]-Step[2700].pt
#
# EPOCH:10 STEP:0
# Total Loss:0.339 	Classification Loss:0.037 	Robustness Loss:81.867 	Concept Loss:0.293 	Accuracy:0.985
# EPOCH:10 STEP:100
# Total Loss:0.341 	Classification Loss:0.041 	Robustness Loss:77.280 	Concept Loss:0.292 	Accuracy:0.990
# EPOCH:10 STEP:200
# Total Loss:0.342 	Classification Loss:0.043 	Robustness Loss:73.014 	Concept Loss:0.293 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.287 	Classification Loss:0.002 	Robustness Loss:0.000 	Concept Loss:0.285 	Accuracy:0.999
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[10]-Step[2970].pt
#
# EPOCH:11 STEP:0
# Total Loss:0.318 	Classification Loss:0.030 	Robustness Loss:76.387 	Concept Loss:0.280 	Accuracy:1.000
# EPOCH:11 STEP:100
# Total Loss:0.312 	Classification Loss:0.027 	Robustness Loss:88.509 	Concept Loss:0.277 	Accuracy:1.000
# EPOCH:11 STEP:200
# Total Loss:0.330 	Classification Loss:0.035 	Robustness Loss:74.378 	Concept Loss:0.288 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.281 	Classification Loss:0.002 	Robustness Loss:0.000 	Concept Loss:0.279 	Accuracy:0.999
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[11]-Step[3240].pt
#
# EPOCH:12 STEP:0
# Total Loss:0.305 	Classification Loss:0.026 	Robustness Loss:82.088 	Concept Loss:0.271 	Accuracy:0.995
# EPOCH:12 STEP:100
# Total Loss:0.302 	Classification Loss:0.020 	Robustness Loss:73.727 	Concept Loss:0.274 	Accuracy:1.000
# EPOCH:12 STEP:200
# Total Loss:0.304 	Classification Loss:0.024 	Robustness Loss:71.572 	Concept Loss:0.273 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.276 	Classification Loss:0.001 	Robustness Loss:0.000 	Concept Loss:0.275 	Accuracy:1.000
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[12]-Step[3510].pt
#
# EPOCH:13 STEP:0
# Total Loss:0.345 	Classification Loss:0.054 	Robustness Loss:72.702 	Concept Loss:0.284 	Accuracy:0.985
# EPOCH:13 STEP:100
# Total Loss:0.308 	Classification Loss:0.029 	Robustness Loss:80.132 	Concept Loss:0.272 	Accuracy:0.995
# EPOCH:13 STEP:200
# Total Loss:0.311 	Classification Loss:0.036 	Robustness Loss:68.377 	Concept Loss:0.268 	Accuracy:0.980
#
# -------- Validation --------
# Total Loss:0.270 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.270 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[13]-Step[3780].pt
#
# EPOCH:14 STEP:0
# Total Loss:0.309 	Classification Loss:0.031 	Robustness Loss:73.540 	Concept Loss:0.270 	Accuracy:0.995
# EPOCH:14 STEP:100
# Total Loss:0.326 	Classification Loss:0.045 	Robustness Loss:76.049 	Concept Loss:0.274 	Accuracy:0.985
# EPOCH:14 STEP:200
# Total Loss:0.318 	Classification Loss:0.045 	Robustness Loss:62.621 	Concept Loss:0.266 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.266 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.265 	Accuracy:1.000
# ----------------------------
# Congratulations! Saving a new best model...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/best_model.pt
#
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[14]-Step[4050].pt
#
# EPOCH:15 STEP:0
# Total Loss:0.308 	Classification Loss:0.030 	Robustness Loss:71.620 	Concept Loss:0.271 	Accuracy:0.990
# EPOCH:15 STEP:100
# Total Loss:0.309 	Classification Loss:0.030 	Robustness Loss:64.544 	Concept Loss:0.273 	Accuracy:0.990
# EPOCH:15 STEP:200
# Total Loss:0.336 	Classification Loss:0.060 	Robustness Loss:73.467 	Concept Loss:0.269 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.261 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.260 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[15]-Step[4320].pt
#
# EPOCH:16 STEP:0
# Total Loss:0.293 	Classification Loss:0.030 	Robustness Loss:69.257 	Concept Loss:0.256 	Accuracy:0.995
# EPOCH:16 STEP:100
# Total Loss:0.306 	Classification Loss:0.043 	Robustness Loss:59.679 	Concept Loss:0.258 	Accuracy:0.980
# EPOCH:16 STEP:200
# Total Loss:0.318 	Classification Loss:0.047 	Robustness Loss:67.671 	Concept Loss:0.264 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.258 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.258 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[16]-Step[4590].pt
#
# EPOCH:17 STEP:0
# Total Loss:0.284 	Classification Loss:0.019 	Robustness Loss:55.119 	Concept Loss:0.259 	Accuracy:0.995
# EPOCH:17 STEP:100
# Total Loss:0.281 	Classification Loss:0.020 	Robustness Loss:55.144 	Concept Loss:0.255 	Accuracy:1.000
# EPOCH:17 STEP:200
# Total Loss:0.301 	Classification Loss:0.038 	Robustness Loss:60.443 	Concept Loss:0.257 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.255 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.255 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[17]-Step[4860].pt
#
# EPOCH:18 STEP:0
# Total Loss:0.306 	Classification Loss:0.048 	Robustness Loss:59.553 	Concept Loss:0.253 	Accuracy:0.990
# EPOCH:18 STEP:100
# Total Loss:0.282 	Classification Loss:0.017 	Robustness Loss:57.736 	Concept Loss:0.259 	Accuracy:1.000
# EPOCH:18 STEP:200
# Total Loss:0.286 	Classification Loss:0.027 	Robustness Loss:48.590 	Concept Loss:0.254 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.252 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.252 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[18]-Step[5130].pt
#
# EPOCH:19 STEP:0
# Total Loss:0.286 	Classification Loss:0.032 	Robustness Loss:64.390 	Concept Loss:0.248 	Accuracy:0.985
# EPOCH:19 STEP:100
# Total Loss:0.287 	Classification Loss:0.030 	Robustness Loss:66.135 	Concept Loss:0.251 	Accuracy:0.985
# EPOCH:19 STEP:200
# Total Loss:0.290 	Classification Loss:0.023 	Robustness Loss:77.567 	Concept Loss:0.259 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.249 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.249 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[19]-Step[5400].pt
#
# EPOCH:20 STEP:0
# Total Loss:0.279 	Classification Loss:0.020 	Robustness Loss:58.183 	Concept Loss:0.253 	Accuracy:1.000
# EPOCH:20 STEP:100
# Total Loss:0.299 	Classification Loss:0.046 	Robustness Loss:58.158 	Concept Loss:0.248 	Accuracy:0.985
# EPOCH:20 STEP:200
# Total Loss:0.299 	Classification Loss:0.041 	Robustness Loss:63.933 	Concept Loss:0.251 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.246 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.246 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[20]-Step[5670].pt
#
# EPOCH:21 STEP:0
# Total Loss:0.273 	Classification Loss:0.025 	Robustness Loss:55.595 	Concept Loss:0.242 	Accuracy:0.995
# EPOCH:21 STEP:100
# Total Loss:0.272 	Classification Loss:0.020 	Robustness Loss:55.110 	Concept Loss:0.247 	Accuracy:1.000
# EPOCH:21 STEP:200
# Total Loss:0.269 	Classification Loss:0.017 	Robustness Loss:53.576 	Concept Loss:0.246 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.244 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.244 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[21]-Step[5940].pt
#
# EPOCH:22 STEP:0
# Total Loss:0.294 	Classification Loss:0.032 	Robustness Loss:56.333 	Concept Loss:0.256 	Accuracy:0.995
# EPOCH:22 STEP:100
# Total Loss:0.280 	Classification Loss:0.030 	Robustness Loss:63.145 	Concept Loss:0.244 	Accuracy:0.990
# EPOCH:22 STEP:200
# Total Loss:0.286 	Classification Loss:0.033 	Robustness Loss:50.585 	Concept Loss:0.247 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.243 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.243 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[22]-Step[6210].pt
#
# EPOCH:23 STEP:0
# Total Loss:0.281 	Classification Loss:0.030 	Robustness Loss:54.813 	Concept Loss:0.246 	Accuracy:1.000
# EPOCH:23 STEP:100
# Total Loss:0.280 	Classification Loss:0.026 	Robustness Loss:52.305 	Concept Loss:0.248 	Accuracy:0.995
# EPOCH:23 STEP:200
# Total Loss:0.269 	Classification Loss:0.024 	Robustness Loss:55.052 	Concept Loss:0.240 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.241 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.241 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[23]-Step[6480].pt
#
# EPOCH:24 STEP:0
# Total Loss:0.274 	Classification Loss:0.027 	Robustness Loss:45.508 	Concept Loss:0.243 	Accuracy:0.995
# EPOCH:24 STEP:100
# Total Loss:0.283 	Classification Loss:0.028 	Robustness Loss:54.712 	Concept Loss:0.250 	Accuracy:1.000
# EPOCH:24 STEP:200
# Total Loss:0.265 	Classification Loss:0.016 	Robustness Loss:45.595 	Concept Loss:0.245 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.238 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.238 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[24]-Step[6750].pt
#
# EPOCH:25 STEP:0
# Total Loss:0.278 	Classification Loss:0.028 	Robustness Loss:53.787 	Concept Loss:0.245 	Accuracy:0.990
# EPOCH:25 STEP:100
# Total Loss:0.257 	Classification Loss:0.019 	Robustness Loss:42.836 	Concept Loss:0.234 	Accuracy:1.000
# EPOCH:25 STEP:200
# Total Loss:0.289 	Classification Loss:0.037 	Robustness Loss:47.147 	Concept Loss:0.247 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.238 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.238 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[25]-Step[7020].pt
#
# EPOCH:26 STEP:0
# Total Loss:0.268 	Classification Loss:0.021 	Robustness Loss:48.749 	Concept Loss:0.242 	Accuracy:1.000
# EPOCH:26 STEP:100
# Total Loss:0.276 	Classification Loss:0.033 	Robustness Loss:44.398 	Concept Loss:0.238 	Accuracy:0.990
# EPOCH:26 STEP:200
# Total Loss:0.267 	Classification Loss:0.026 	Robustness Loss:51.635 	Concept Loss:0.237 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.236 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.236 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[26]-Step[7290].pt
#
# EPOCH:27 STEP:0
# Total Loss:0.272 	Classification Loss:0.032 	Robustness Loss:44.236 	Concept Loss:0.235 	Accuracy:0.990
# EPOCH:27 STEP:100
# Total Loss:0.254 	Classification Loss:0.016 	Robustness Loss:48.814 	Concept Loss:0.234 	Accuracy:1.000
# EPOCH:27 STEP:200
# Total Loss:0.262 	Classification Loss:0.021 	Robustness Loss:46.028 	Concept Loss:0.237 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.235 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.235 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[27]-Step[7560].pt
#
# EPOCH:28 STEP:0
# Total Loss:0.251 	Classification Loss:0.011 	Robustness Loss:47.672 	Concept Loss:0.235 	Accuracy:1.000
# EPOCH:28 STEP:100
# Total Loss:0.276 	Classification Loss:0.033 	Robustness Loss:41.394 	Concept Loss:0.239 	Accuracy:0.995
# EPOCH:28 STEP:200
# Total Loss:0.298 	Classification Loss:0.062 	Robustness Loss:45.124 	Concept Loss:0.231 	Accuracy:0.975
#
# -------- Validation --------
# Total Loss:0.233 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.233 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[28]-Step[7830].pt
#
# EPOCH:29 STEP:0
# Total Loss:0.261 	Classification Loss:0.025 	Robustness Loss:39.578 	Concept Loss:0.232 	Accuracy:0.995
# EPOCH:29 STEP:100
# Total Loss:0.264 	Classification Loss:0.027 	Robustness Loss:45.758 	Concept Loss:0.232 	Accuracy:0.995
# EPOCH:29 STEP:200
# Total Loss:0.276 	Classification Loss:0.040 	Robustness Loss:45.430 	Concept Loss:0.231 	Accuracy:0.985
#
# -------- Validation --------
# Total Loss:0.233 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.233 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[29]-Step[8100].pt
#
# EPOCH:30 STEP:0
# Total Loss:0.258 	Classification Loss:0.016 	Robustness Loss:54.344 	Concept Loss:0.237 	Accuracy:0.995
# EPOCH:30 STEP:100
# Total Loss:0.253 	Classification Loss:0.017 	Robustness Loss:38.349 	Concept Loss:0.233 	Accuracy:1.000
# EPOCH:30 STEP:200
# Total Loss:0.250 	Classification Loss:0.019 	Robustness Loss:38.378 	Concept Loss:0.227 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.232 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.232 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[30]-Step[8370].pt
#
# EPOCH:31 STEP:0
# Total Loss:0.259 	Classification Loss:0.025 	Robustness Loss:41.165 	Concept Loss:0.230 	Accuracy:0.995
# EPOCH:31 STEP:100
# Total Loss:0.263 	Classification Loss:0.024 	Robustness Loss:65.040 	Concept Loss:0.233 	Accuracy:1.000
# EPOCH:31 STEP:200
# Total Loss:0.251 	Classification Loss:0.018 	Robustness Loss:45.535 	Concept Loss:0.228 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.230 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.230 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[31]-Step[8640].pt
#
# EPOCH:32 STEP:0
# Total Loss:0.249 	Classification Loss:0.022 	Robustness Loss:44.775 	Concept Loss:0.222 	Accuracy:1.000
# EPOCH:32 STEP:100
# Total Loss:0.252 	Classification Loss:0.017 	Robustness Loss:51.727 	Concept Loss:0.230 	Accuracy:1.000
# EPOCH:32 STEP:200
# Total Loss:0.275 	Classification Loss:0.033 	Robustness Loss:42.904 	Concept Loss:0.238 	Accuracy:0.990
#
# -------- Validation --------
# Total Loss:0.229 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.229 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[32]-Step[8910].pt
#
# EPOCH:33 STEP:0
# Total Loss:0.271 	Classification Loss:0.031 	Robustness Loss:42.127 	Concept Loss:0.236 	Accuracy:0.985
# EPOCH:33 STEP:100
# Total Loss:0.257 	Classification Loss:0.021 	Robustness Loss:49.610 	Concept Loss:0.231 	Accuracy:0.995
# EPOCH:33 STEP:200
# Total Loss:0.282 	Classification Loss:0.041 	Robustness Loss:38.458 	Concept Loss:0.237 	Accuracy:0.970
#
# -------- Validation --------
# Total Loss:0.228 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.228 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[33]-Step[9180].pt
#
# EPOCH:34 STEP:0
# Total Loss:0.263 	Classification Loss:0.031 	Robustness Loss:36.369 	Concept Loss:0.228 	Accuracy:0.995
# EPOCH:34 STEP:100
# Total Loss:0.254 	Classification Loss:0.022 	Robustness Loss:41.511 	Concept Loss:0.228 	Accuracy:0.995
# EPOCH:34 STEP:200
# Total Loss:0.255 	Classification Loss:0.020 	Robustness Loss:39.242 	Concept Loss:0.232 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.228 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.228 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[34]-Step[9450].pt
#
# EPOCH:35 STEP:0
# Total Loss:0.260 	Classification Loss:0.022 	Robustness Loss:40.235 	Concept Loss:0.234 	Accuracy:0.995
# EPOCH:35 STEP:100
# Total Loss:0.258 	Classification Loss:0.029 	Robustness Loss:37.649 	Concept Loss:0.225 	Accuracy:0.995
# EPOCH:35 STEP:200
# Total Loss:0.248 	Classification Loss:0.017 	Robustness Loss:47.041 	Concept Loss:0.226 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.227 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.227 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[35]-Step[9720].pt
#
# EPOCH:36 STEP:0
# Total Loss:0.254 	Classification Loss:0.021 	Robustness Loss:35.735 	Concept Loss:0.229 	Accuracy:1.000
# EPOCH:36 STEP:100
# Total Loss:0.261 	Classification Loss:0.026 	Robustness Loss:42.423 	Concept Loss:0.231 	Accuracy:0.995
# EPOCH:36 STEP:200
# Total Loss:0.267 	Classification Loss:0.023 	Robustness Loss:34.877 	Concept Loss:0.240 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.226 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.226 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[36]-Step[9990].pt
#
# EPOCH:37 STEP:0
# Total Loss:0.240 	Classification Loss:0.018 	Robustness Loss:37.942 	Concept Loss:0.219 	Accuracy:0.995
# EPOCH:37 STEP:100
# Total Loss:0.245 	Classification Loss:0.017 	Robustness Loss:46.812 	Concept Loss:0.223 	Accuracy:1.000
# EPOCH:37 STEP:200
# Total Loss:0.238 	Classification Loss:0.014 	Robustness Loss:34.156 	Concept Loss:0.221 	Accuracy:0.995
#
# -------- Validation --------
# Total Loss:0.225 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.225 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[37]-Step[10260].pt
#
# EPOCH:38 STEP:0
# Total Loss:0.249 	Classification Loss:0.014 	Robustness Loss:39.700 	Concept Loss:0.231 	Accuracy:1.000
# EPOCH:38 STEP:100
# Total Loss:0.249 	Classification Loss:0.024 	Robustness Loss:53.515 	Concept Loss:0.221 	Accuracy:0.995
# EPOCH:38 STEP:200
# Total Loss:0.240 	Classification Loss:0.015 	Robustness Loss:38.731 	Concept Loss:0.221 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.225 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.225 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[38]-Step[10530].pt
#
# EPOCH:39 STEP:0
# Total Loss:0.245 	Classification Loss:0.017 	Robustness Loss:50.517 	Concept Loss:0.224 	Accuracy:1.000
# EPOCH:39 STEP:100
# Total Loss:0.256 	Classification Loss:0.018 	Robustness Loss:39.741 	Concept Loss:0.234 	Accuracy:1.000
# EPOCH:39 STEP:200
# Total Loss:0.235 	Classification Loss:0.013 	Robustness Loss:49.547 	Concept Loss:0.216 	Accuracy:1.000
#
# -------- Validation --------
# Total Loss:0.224 	Classification Loss:0.000 	Robustness Loss:0.000 	Concept Loss:0.224 	Accuracy:1.000
# ----------------------------
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[39]-Step[10800].pt
#
# Please wait while we finalize...
# Checkpoint saved @ results/CONF_FASHION_MNIST/checkpoints/Epoch[39]-Step[10800].pt

# %%
# !git add -f results/

# %%
# !git commit -m "Force add results folder"
# !git remote set-url origin https://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@github.com/Ggenoni/SENN.git
# !git push --force origin master
# Out:
# [master 2732928] Force add results folder
#  54 files changed, 160 insertions(+)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[0]-Step[270].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[10]-Step[2970].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[11]-Step[3240].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[12]-Step[3510].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[13]-Step[3780].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[14]-Step[4050].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[15]-Step[4320].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[16]-Step[4590].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[17]-Step[4860].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[18]-Step[5130].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[19]-Step[5400].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[1]-Step[540].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[20]-Step[5670].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[21]-Step[5940].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[22]-Step[6210].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[23]-Step[6480].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[24]-Step[6750].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[25]-Step[7020].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[26]-Step[7290].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[27]-Step[7560].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[28]-Step[7830].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[29]-Step[8100].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[2]-Step[810].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[30]-Step[8370].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[31]-Step[8640].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[32]-Step[8910].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[33]-Step[9180].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[34]-Step[9450].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[35]-Step[9720].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[36]-Step[9990].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[37]-Step[10260].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[38]-Step[10530].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[39]-Step[10800].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[3]-Step[1080].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[4]-Step[1350].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[5]-Step[1620].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[6]-Step[1890].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[7]-Step[2160].pt (90%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[8]-Step[2430].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/Epoch[9]-Step[2700].pt (91%)
#  rewrite results/CONF_FASHION_MNIST/checkpoints/best_model.pt (91%)
#  rewrite results/CONF_FASHION_MNIST/explanation_0.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_1.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_2.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_3.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_4.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_5.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_6.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_7.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_8.png (99%)
#  rewrite results/CONF_FASHION_MNIST/explanation_9.png (99%)
#  create mode 100644 results/CONF_FASHION_MNIST/logs/events.out.tfevents.1738237576.32eda084f61c.974.0
# Enumerating objects: 110, done.
# Counting objects: 100% (110/110), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (60/60), done.
# Writing objects: 100% (60/60), 13.66 MiB | 6.25 MiB/s, done.
# Total 60 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/Ggenoni/SENN.git
#    64acc76..2732928  master -> master

# %% [markdown]
# ### 2. Evaluating the trained SENN model and its learned concepts

# %% [markdown]
# ##### 2.1 Imports and set up

# %%
import json
import torch
import random
import numpy as np
import torch.nn as nn
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from pathlib import Path
from types import SimpleNamespace
from importlib import import_module

# %%
! pwd
# Out:
# /content/SENN

# %%
from senn.models.losses import *
from senn.models.parameterizers import *
from senn.models.conceptizers import *
from senn.models.aggregators import *
from senn.models.senn import SENN, DiSENN

# %%
from senn.datasets.dataloaders import get_dataloader
from senn.utils.plot_utils import show_explanations, show_prototypes, plot_lambda_accuracy, get_comparison_plot
from senn.utils.custom_functions import plot_samples

# %%
def load_checkpoint(config):
    model_file = Path('results') / config.exp_name / "checkpoints" / "best_model.pt"
    return torch.load(model_file, config.device)

# %%
def get_config(filename):
    config_path = Path('configs')
    config_file = config_path / filename
    with open(config_file, 'r') as f:
        config = json.load(f)

    return SimpleNamespace(**config)

# %%
def accuracy(model, dataloader, config):
    accuracies = []
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Auto-detect device

    model.to(device)  # Ensure model is on correct device
    with torch.no_grad():
        for i, (x, labels) in enumerate(dataloader):
            x = x.float().to(device)  # Move input tensors to device
            labels = labels.long().to(device)  # Move labels to device
            y_pred, (concepts, relevances), _ = model(x)
            accuracies.append((y_pred.argmax(axis=1) == labels).float().mean().item())

    accuracy = np.array(accuracies).mean()
    print(f"Test Mean Accuracy: {accuracy * 100:.3f} %")

# %%
mnist_config = get_config("conf_mnist_config.json")

# %% [markdown]
# ##### 2.2 Getting the dataset

# %%
mnist_train_dl, mnist_validation_dl, mnist_test_dl = get_dataloader(mnist_config)

# %%
## PLOT MNIST SAMPLES (1 sample from training set, 1 from validation set, 2 from test set)

plot_samples(
    mnist_train_samples,
    mnist_validation_samples,
    mnist_test_samples,
    "MNIST Samples - Train, Validation, and Test"
)

# %% [markdown]
# ##### 2.3 Getting the model and loading the trained parameters

# %%
conceptizer = ConvConceptizer(**mnist_config.__dict__)
parameterizer = ConvParameterizer(**mnist_config.__dict__)
aggregator = SumAggregator(**mnist_config.__dict__)

mnist_SENN = SENN(conceptizer, parameterizer, aggregator)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Construct checkpoint path properly
checkpoint_path = Path("results") / mnist_config.exp_name / "checkpoints" / "best_model.pt"

# Load the checkpoint
mnist_checkpoint = torch.load(checkpoint_path, map_location=device)
mnist_SENN.load_state_dict(mnist_checkpoint['model_state'])
mnist_SENN.to(device)  # Move model to the appropriate device
# Out:
# <ipython-input-44-5281cb37beaf>:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mnist_checkpoint = torch.load(checkpoint_path, map_location=device)
# SENN(
#   (conceptizer): ConvConceptizer(
#     (encoder): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(10, 5, kernel_size=(5, 5), stride=(1, 1))
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#       (2): ScalarMapping(
#         (layers): ModuleList(
#           (0-4): 5 x Linear(in_features=16, out_features=1, bias=True)
#         )
#       )
#     )
#     (decoder): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(5, 16, kernel_size=(5, 5), stride=(2, 2))
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): ConvTranspose2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): ConvTranspose2d(8, 1, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#       )
#       (5): Tanh()
#     )
#     (unlinear): Linear(in_features=1, out_features=16, bias=True)
#   )
#   (parameterizer): ConvParameterizer(
#     (cl_layers): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ReLU()
#       (3): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#       (4): Dropout2d(p=0.5, inplace=False)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): ReLU()
#     )
#     (fc_layers): Sequential(
#       (0): Linear(in_features=320, out_features=50, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): Tanh()
#     )
#   )
#   (aggregator): SumAggregator()
# )

# %% [markdown]
# ##### 2.4 Evaluating accuracy on validation and test sets

# %%
accuracy(mnist_SENN, mnist_validation_dl, mnist_config)
# Out:
# Test Mean Accuracy: 100.000 %

# %%
accuracy(mnist_SENN, mnist_test_dl, mnist_config)
# Out:
# Test Mean Accuracy: 34.010 %

# %% [markdown]
# ##### 2.5 Concept prototypes

# %%
show_prototypes(mnist_SENN, mnist_test_dl, 'activation')

# %% [markdown]
# ##### 2.6 Getting sample indeces
# 1 randomly chosen sample for each class (10 in total).
# Setting seeds allows reproducibility of the experiment.

# %%
import torch
import random
import numpy as np

# Ensure reproducibility
torch.manual_seed(10)
np.random.seed(10)
random.seed(10)

# Get the dataset
dataset = mnist_test_dl.dataset
total_samples = len(dataset)

# Initialize a dictionary to store one sample per class
class_indices = {i: None for i in range(10)}  # Classes are 0-9
random_indices = []

# Shuffle the dataset indices to ensure randomness
shuffled_indices = torch.randperm(total_samples).tolist()

# Iterate through the shuffled indices
for idx in shuffled_indices:
    img, label = dataset[idx]
    if class_indices[label] is None:
        class_indices[label] = idx
        random_indices.append((idx, label))  # Append both index and label
    # Break the loop once we have one sample per class
    if len(random_indices) == 10:
        break

# Sort the indices by label
random_indices_sorted = sorted(random_indices, key=lambda x: x[1])

# Extract only the indices in the correct order
random_indices = [idx for idx, _ in random_indices_sorted]

print("Ordered random indices, one per class:", random_indices)
# Out:
# Ordered random indices, one per class: [6937, 7468, 837, 3531, 5561, 8415, 5034, 6762, 7735, 3992]

# %% [markdown]
# ##### 2.7 SENN explanations

# %%
# Rememer to save the images!!!!

show_explanations(mnist_SENN, mnist_test_dl, 'mnist', selected_indices=random_indices)

# %% [markdown]
# ##### 2.8 Ablation study and statistics on relevance scores

# %%
from senn.utils.custom_functions import evaluate_concept_ablation,analyze_relevance_scores_by_predicted_class, analyze_class_specific_relevance

# %%
# Ablation study

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
mnist_SENN.to(device)

concepts = [0, 1, 2, 3, 4]

for i in range(len(concepts)):

    ablated_concepts= concepts[:i]+concepts[i+1:]

    # Evaluate concept ablation
    original_preds, ablated_preds, impact = evaluate_concept_ablation(
        mnist_SENN, mnist_test_dl, ablated_concepts, device=device
    )

    # Calculate the percentage of predictions affected by ablation
    percentage_changed = 100 * sum(impact) / len(impact)
    print(f"Percentage of Predictions Changed by Ablating Concepts {ablated_concepts}: {percentage_changed:.2f}%")
    # Analyze results
    print(f"Original Predictions: {original_preds[:10]}")
    print(f"Ablated Predictions: {ablated_preds[:10]}")
    print(f"Impact on Predictions: {impact[:10]} (True = Changed, False = Unchanged)")
    print("\n\n")
# Out:
# Percentage of Predictions Changed by Ablating Concepts [1, 2, 3, 4]: 9.46%
# Original Predictions: [0, 8, 1, 0, 4, 1, 8, 3, 6, 8]
# Ablated Predictions: [0, 2, 1, 0, 4, 1, 8, 3, 6, 8]
# Impact on Predictions: [False, True, False, False, False, False, False, False, False, False] (True = Changed, False = Unchanged)
# Percentage of Predictions Changed by Ablating Concepts [0, 2, 3, 4]: 8.31%
# Original Predictions: [3, 9, 1, 0, 0, 2, 8, 2, 0, 8]
# Ablated Predictions: [3, 9, 1, 0, 0, 2, 8, 2, 0, 3]
# Impact on Predictions: [False, False, False, False, False, False, False, False, False, True] (True = Changed, False = Unchanged)
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 3, 4]: 10.95%
# Original Predictions: [9, 2, 1, 0, 6, 6, 8, 4, 6, 0]
# Ablated Predictions: [9, 2, 1, 0, 6, 6, 9, 4, 6, 0]
# Impact on Predictions: [False, False, False, False, False, False, True, False, False, False] (True = Changed, False = Unchanged)
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 2, 4]: 8.49%
# Original Predictions: [2, 8, 6, 0, 4, 1, 8, 4, 6, 8]
# Ablated Predictions: [2, 8, 6, 0, 4, 1, 6, 4, 6, 8]
# Impact on Predictions: [False, False, False, False, False, False, True, False, False, False] (True = Changed, False = Unchanged)
# Percentage of Predictions Changed by Ablating Concepts [0, 1, 2, 3]: 8.96%
# Original Predictions: [3, 2, 1, 5, 0, 2, 8, 3, 5, 9]
# Ablated Predictions: [3, 8, 1, 5, 0, 2, 8, 3, 6, 9]
# Impact on Predictions: [False, True, False, False, False, False, False, False, True, False] (True = Changed, False = Unchanged)

# %%
# Number of concepts
num_concepts = 5

# Analyze relevance scores
relevance_stats = analyze_relevance_scores_by_predicted_class(
    mnist_SENN, mnist_test_dl, num_concepts=num_concepts, device=device
)

# Display statistics
print("Relevance Score Statistics:")
for concept, stats in relevance_stats.items():
    print(f"Concept {int(concept)+1}: Mean = {stats['mean']:.4f}, Std = {stats['std']:.4f}")
# Out:
# Relevance Score Statistics:
# Concept 1: Mean = -0.4492, Std = 0.1942
# Concept 2: Mean = 0.4430, Std = 0.1927
# Concept 3: Mean = -0.4714, Std = 0.2007
# Concept 4: Mean = 0.4893, Std = 0.1981
# Concept 5: Mean = -0.4506, Std = 0.1986

# %%
# Number of classes in MNIST
num_classes = 10

# Number of concepts
num_concepts = 5

# Analyze class-specific relevance
class_relevance_stats = analyze_class_specific_relevance(
    mnist_SENN, mnist_test_dl, num_classes=num_classes, num_concepts=num_concepts, device=device
)

# Display the statistics
for cls, stats in class_relevance_stats.items():
    print(f"Class {cls} Relevance Scores:")
    for concept, values in stats.items():
        print(f"  {concept}: Mean = {values['mean']:.4f}, Std = {values['std']:.4f}")
# Out:
# Class 0 Relevance Scores:
#   Concept 1: Mean = -0.5398, Std = 0.1753
#   Concept 2: Mean = 0.5435, Std = 0.2096
#   Concept 3: Mean = -0.5796, Std = 0.1814
#   Concept 4: Mean = 0.5479, Std = 0.1713
#   Concept 5: Mean = -0.5432, Std = 0.1704
# Class 1 Relevance Scores:
#   Concept 1: Mean = -0.4150, Std = 0.1214
#   Concept 2: Mean = 0.4099, Std = 0.0958
#   Concept 3: Mean = -0.4372, Std = 0.1154
#   Concept 4: Mean = 0.5008, Std = 0.1151
#   Concept 5: Mean = -0.4351, Std = 0.1035
# Class 2 Relevance Scores:
#   Concept 1: Mean = -0.4874, Std = 0.2029
#   Concept 2: Mean = 0.4989, Std = 0.2028
#   Concept 3: Mean = -0.4918, Std = 0.2242
#   Concept 4: Mean = 0.4836, Std = 0.2347
#   Concept 5: Mean = -0.5027, Std = 0.1977
# Class 3 Relevance Scores:
#   Concept 1: Mean = -0.4288, Std = 0.1739
#   Concept 2: Mean = 0.4733, Std = 0.1892
#   Concept 3: Mean = -0.4207, Std = 0.1995
#   Concept 4: Mean = 0.4852, Std = 0.1955
#   Concept 5: Mean = -0.4282, Std = 0.1903
# Class 4 Relevance Scores:
#   Concept 1: Mean = -0.4956, Std = 0.1897
#   Concept 2: Mean = 0.4679, Std = 0.1860
#   Concept 3: Mean = -0.4559, Std = 0.1711
#   Concept 4: Mean = 0.5071, Std = 0.1967
#   Concept 5: Mean = -0.4776, Std = 0.1996
# Class 5 Relevance Scores:
#   Concept 1: Mean = -0.4136, Std = 0.1807
#   Concept 2: Mean = 0.4421, Std = 0.2013
#   Concept 3: Mean = -0.4415, Std = 0.2038
#   Concept 4: Mean = 0.4831, Std = 0.1903
#   Concept 5: Mean = -0.4111, Std = 0.2060
# Class 6 Relevance Scores:
#   Concept 1: Mean = -0.5337, Std = 0.1869
#   Concept 2: Mean = 0.4924, Std = 0.2067
#   Concept 3: Mean = -0.5860, Std = 0.2112
#   Concept 4: Mean = 0.5596, Std = 0.1873
#   Concept 5: Mean = -0.5634, Std = 0.1970
# Class 7 Relevance Scores:
#   Concept 1: Mean = -0.5515, Std = 0.2015
#   Concept 2: Mean = 0.4059, Std = 0.1859
#   Concept 3: Mean = -0.5160, Std = 0.2038
#   Concept 4: Mean = 0.5826, Std = 0.2027
#   Concept 5: Mean = -0.4980, Std = 0.2181
# Class 8 Relevance Scores:
#   Concept 1: Mean = -0.2772, Std = 0.1554
#   Concept 2: Mean = 0.3768, Std = 0.1683
#   Concept 3: Mean = -0.3742, Std = 0.1847
#   Concept 4: Mean = 0.3443, Std = 0.1663
#   Concept 5: Mean = -0.3616, Std = 0.1669
# Class 9 Relevance Scores:
#   Concept 1: Mean = -0.3488, Std = 0.1509
#   Concept 2: Mean = 0.3268, Std = 0.1651
#   Concept 3: Mean = -0.4153, Std = 0.1861
#   Concept 4: Mean = 0.3959, Std = 0.1818
#   Concept 5: Mean = -0.2862, Std = 0.1515

# %% [markdown]
# ### 3. Integrated Gradients

# %% [markdown]
# ##### 3.1 Imports and set up

# %%
from captum.attr import IntegratedGradients
from skimage.metrics import structural_similarity as ssim
from torchvision.transforms import functional as TF
import random

# %%
from senn.models.senn import SENNWrapper

# %%
from senn.utils.custom_functions import compute_completeness_gap, sensitivity_analysis, apply_challenging_transformations

# %%
# Use our SENN wrapper to make the model compatible with Integrated Gradients implemented in the captum library
wrapped_model = SENNWrapper(mnist_SENN)
ig = IntegratedGradients(wrapped_model)
# Get the device of the model

device = next(wrapped_model.parameters()).device

# %% [markdown]
# ##### 3.2 Getting the data samples

# %%
## Uncomment the code below to run the analysis on other test samples

# Ensure reproducibility
"""torch.manual_seed(110)
np.random.seed(110)
random.seed(100)"""

# Number of random samples to analyze
"""num_samples = 10"""

# Get the dataset
"""dataset = mnist_test_dl.dataset
total_samples = len(dataset)"""

# Randomly pick indices for the samples
"""random_indices = torch.randint(0, total_samples, (num_samples,)).tolist()"""

# %% [markdown]
# ##### 3.3 Attribution maps and completeness gap

# %%
for i, random_index in enumerate(random_indices):
    # Retrieve the sample and label
    sample_input, sample_label = dataset[random_index]

    # Add batch dimension and move to the model's device
    sample_input = sample_input.unsqueeze(0).to(device)

    # Define the baseline (e.g., a black image) and move it to the same device
    baseline = torch.zeros_like(sample_input).to(device)

    # Get the predicted label
    with torch.no_grad():
        predictions = wrapped_model(sample_input)
        predicted_label = torch.argmax(predictions, dim=1).item()

    # Compute completeness gap and attributions
    completeness_gap, attributions = compute_completeness_gap(
        wrapped_model, sample_input, baseline, predicted_label
    )

    print(f"Sample {i + 1}: Completeness Gap = {completeness_gap:.4f}")

    # Prepare data for visualization
    attributions = attributions.squeeze().detach().cpu().numpy()  # Move to CPU for visualization
    attributions = attributions / np.max(np.abs(attributions))  # Normalize
    original_image = sample_input.squeeze().cpu().numpy()  # Move to CPU for visualization

    # Determine bounds for the colormap
    cmap_bound = np.abs(attributions).max()

    # Create a 1-row, 2-column plot
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    # Original image
    ax[0].imshow(original_image, cmap="gray")
    ax[0].set_title(f"Original Image\nLabel: {sample_label}")
    ax[0].axis("off")

    # Attributions (Raw)
    im = ax[1].imshow(attributions, vmin=-cmap_bound, vmax=cmap_bound, cmap="PiYG")
    ax[1].set_title(f"Attributions\nPredicted: {predicted_label}")
    ax[1].axis("off")

    # Add a colorbar to the attributions plot
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust colorbar position
    cbar = fig.colorbar(im, cax=cbar_ax)
    cbar.set_label("Attribution Value", rotation=270, labelpad=15)

    # Manually adjust spacing between plots
    fig.subplots_adjust(wspace=0.3, hspace=0.3)

    # Display the plot
    plt.show()

    print("\n\n")
# Out:
# Sample 1: Completeness Gap = 0.0015
# Sample 2: Completeness Gap = 0.0119
# Sample 3: Completeness Gap = 0.0021
# Sample 4: Completeness Gap = 0.0043
# Sample 5: Completeness Gap = 0.0101
# Sample 6: Completeness Gap = 0.0003
# Sample 7: Completeness Gap = 0.0161
# Sample 8: Completeness Gap = 0.0002
# Sample 9: Completeness Gap = 0.0177
# Sample 10: Completeness Gap = 0.0026

# %% [markdown]
# ### 4. LIME

# %% [markdown]
# ##### 4.1 Impotrs and set up

# %% [markdown]
# ##### 4.1 Imports and set up

# %%
# Import needed libraries
from lime import lime_image
from skimage.segmentation import mark_boundaries, slic
from skimage.color import gray2rgb, rgb2gray, label2rgb
from lime.wrappers.scikit_image import SegmentationAlgorithm
from functools import partial

# %%
from functions import predict_function, predict_on_masked_superpixels, segmenter

# %%
# Initialize the LIME Image Explainer
explainer = lime_image.LimeImageExplainer()

# %% [markdown]
# ##### 4.2 Getting the datat samples

# %%
## Uncomment the code below to run the analysis on other test samples

# Ensure reproducibility
"""torch.manual_seed(110)
np.random.seed(110)
random.seed(100)"""

# Number of random samples to analyze
"""num_samples = 5"""

# Get the dataset
"""dataset = mnist_test_dl.dataset
total_samples = len(dataset)"""

# Randomly pick indices for the samples
"""random_indices = torch.randint(0, total_samples, (num_samples,)).tolist()"""

# %% [markdown]
# ##### 4.3 Superpixel segmentation and LIME *explanations*

# %%
# Bind the model to the prediction function
predict_with_model = partial(predict_function, model=mnist_SENN)

num_samples = 10

# Initialize the figure
fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

for i, random_index in enumerate(random_indices):
    # Select the image and label at the random index
    sample_image, sample_label = dataset[random_index]
    sample_image = sample_image.squeeze(0).numpy()  # Convert to 2D array

    # Convert grayscale image to RGB
    sample_image_rgb = gray2rgb(sample_image)  # Convert grayscale to RGB (HxWxC)

    # Generate LIME explanation
    explanation = explainer.explain_instance(
        image=sample_image_rgb,
        classifier_fn=predict_with_model,
        top_labels=1,
        hide_color=0,
        num_samples=1000,
        segmentation_fn=segmenter
    )

    # Get the explanation mask
    temp, mask = explanation.get_image_and_mask(
        label=explanation.top_labels[0],
        positive_only=True,  # Highlight only positive contributions
        num_features=10,
        hide_rest=False
    )

    # Extract explanation score (sum of positive contributions)
    explanation_score = sum(
        weight for feature, weight in explanation.local_exp[explanation.top_labels[0]]
        if weight > 0
    )

    # Clip the temp image to ensure valid intensity values
    temp = np.clip(temp, 0, 1)

    # Generate the LIME explanation overlay
    rgb_output = label2rgb(mask, temp, bg_label=0)

    # Clip the RGB output to valid range for floats ([0, 1])
    rgb_output = np.clip(rgb_output, 0, 1)

    # Visualize original image
    axes[i, 0].imshow(sample_image, cmap='gray')
    axes[i, 0].set_title(f"Original Image\nTrue Label: {sample_label}")
    axes[i, 0].axis('off')

    # Visualize superpixel segmentation
    axes[i, 1].imshow(mark_boundaries(sample_image_rgb, segmenter(sample_image_rgb)))
    axes[i, 1].set_title("Superpixel Segmentation")
    axes[i, 1].axis('off')

    # Visualize LIME explanation with overlay
    axes[i, 2].imshow(rgb_output, interpolation='nearest')
    axes[i, 2].set_title(
        f"LIME Explanation\nPredicted Label: {explanation.top_labels[0]}\nScore: {explanation_score:.2f}"
    )
    axes[i, 2].axis('off')

# Adjust layout for better visualization
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##### 4.4 Special focus on class 0

# %%
# Initialize the LIME Image Explainer
explainer = lime_image.LimeImageExplainer()

# %%
# Ensure reproducibility
torch.manual_seed(10)
np.random.seed(10)
random.seed(10)

# Get the dataset
dataset = mnist_test_dl.dataset
total_samples = len(dataset)

# Filter indices for class 0
class_0_indices = [idx for idx in range(total_samples) if dataset[idx][1] == 0]

# Shuffle and select `num_samples` images from class 0
num_samples = 10  # Set the number of samples you want
class_0_indices = random.sample(class_0_indices, num_samples)

print("Selected random indices for class 0:", class_0_indices)
# Out:
# Selected random indices for class 0: [6181, 407, 4757, 5320, 6259, 192, 2417, 5133, 8558, 5415]

# %%
# Bind the model to the prediction function
predict_with_model = partial(predict_function, model=mnist_SENN)

num_samples = 10

# Initialize the figure
fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

for i, random_index in enumerate(class_0_indices):
    # Select the image and label at the random index
    sample_image, sample_label = dataset[random_index]
    sample_image = sample_image.squeeze(0).numpy()  # Convert to 2D array

    # Convert grayscale image to RGB
    sample_image_rgb = gray2rgb(sample_image)  # Convert grayscale to RGB (HxWxC)

    # Generate LIME explanation
    explanation = explainer.explain_instance(
        image=sample_image_rgb,
        classifier_fn=predict_with_model,
        top_labels=1,
        hide_color=0,
        num_samples=1000,
        segmentation_fn=segmenter
    )

    # Get the explanation mask
    temp, mask = explanation.get_image_and_mask(
        label=explanation.top_labels[0],
        positive_only=True,  # Highlight only positive contributions
        num_features=10,
        hide_rest=False
    )

    # Extract explanation score (sum of positive contributions)
    explanation_score = sum(
        weight for feature, weight in explanation.local_exp[explanation.top_labels[0]]
        if weight > 0
    )

    # Clip the temp image to ensure valid intensity values
    temp = np.clip(temp, 0, 1)

    # Generate the LIME explanation overlay
    rgb_output = label2rgb(mask, temp, bg_label=0)

    # Clip the RGB output to valid range for floats ([0, 1])
    rgb_output = np.clip(rgb_output, 0, 1)

    # Visualize original image
    axes[i, 0].imshow(sample_image, cmap='gray')
    axes[i, 0].set_title(f"Original Image\nTrue Label: {sample_label}")
    axes[i, 0].axis('off')

    # Visualize superpixel segmentation
    axes[i, 1].imshow(mark_boundaries(sample_image_rgb, segmenter(sample_image_rgb)))
    axes[i, 1].set_title("Superpixel Segmentation")
    axes[i, 1].axis('off')

    # Visualize LIME explanation with overlay
    axes[i, 2].imshow(rgb_output, interpolation='nearest')
    axes[i, 2].set_title(
        f"LIME Explanation\nPredicted Label: {explanation.top_labels[0]}\nScore: {explanation_score:.2f}"
    )
    axes[i, 2].axis('off')

# Adjust layout for better visualization
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
